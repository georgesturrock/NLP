# %% [markdown]
# ## Noun Phrase Chunking of IMDB Movie Reviews
# ### DS 7337 - Natural Laguage Processing - Homework 5
# #### George C. Sturrock
# ##### March 2, 2019
# ##### Homework 5 Objectives
# 1.	Compile a list of static links (permalinks) to individual user movie reviews from one particular website. This will be your working dataset for this assignment, as well as for assignments 7 and 8, which together will make up your semester project.
# a.	It does not matter if you use a crawler or if you manually collect the links, but you will need at least 100 movie review links. Note that, as of this writing, the robots.txt file of IMDB.com allows the crawling of user reviews.
# b.	Each link should be to a web page that has only one user review of only one movie, e.g., the user review permalinks on the IMDB site.
# c.	Choose reviews of movies that are all in the same genre, e.g., sci-fi, mystery, romance, superhero, etc.
# d.	Make sure your collection includes reviews of several movies in your chosen genre and that it includes a mix of negative and positive reviews.
#
# 2.	Extract noun phrase (NP) chunks from your reviews using the following procedure:
# a.	In Python, use BeautifulSoup to grab the main review text from each link.
# b.	Next run each review text through a tokenizer, and then try to NP-chunk it with a shallow parser.
# c.	You probably will have too many unknown words, owing to proper names of characters, actors, and so on that are not in your working dictionary. Make sure the main names that are relevant to the movies in your collection of reviews are added to the working lexicon, and then run the NP chunker again.
#
# 3.	Output all the chunks in a single list for each review, and submit that output for this assignment. Also submit a brief written summary of what you did (describe your selection of genre, your source of reviews, how many you collected, and by what means).
#
# #### Import Libraries

# %%
import platform; print("Platform:", platform.platform())
import os
import sys; print("Python:", sys.version)
import requests; print("Requests:", requests.__version__)
from urllib import request; ("urllib:", request.__version__)
import warnings
warnings.filterwarnings('ignore')
from time import sleep

#Web Scraping
import bs4; print("BeatifulSoup:", bs4.__version__)
from bs4 import BeautifulSoup
import json; print("json:", json.__version__)

#Python Basics
import numpy as np; print("Numpy Version:", np.__version__)
import pandas as pd; print("Pandas Version:", pd.__version__)

#NLP
import nltk; print("NLTK Version:", nltk.__version__)
#nltk.download('conll2000')
from nltk.corpus import conll2000

import spacy; print("Spacy Version:", spacy.__version__)
from spacy import displacy
#nlp = spacy.load('en')
import en_core_web_sm; print("en_core_web_sm Version:", en_core_web_sm.__version__)
nlp = en_core_web_sm.load()

import pattern; print("Pattern Version:", pattern.__version__)
from pattern.en import tag
from pattern.en import parsetree
# Out:
# Platform: Windows-10-10.0.14393-SP0
# Python: 3.6.8 |Anaconda custom (64-bit)| (default, Feb 11 2019, 15:03:47) [MSC v.1915 64 bit (AMD64)]
# Requests: 2.21.0
# BeatifulSoup: 4.7.1
# json: 2.0.9
# Numpy Version: 1.15.4
# Pandas Version: 0.24.1
# NLTK Version: 3.4
# Spacy Version: 2.0.16
# en_core_web_sm Version: 2.0.0
# Pattern Version: 3.6

# %% [markdown]
# #### Question 5.1
# For this assignment, the first three films in the "Rocky" series will be utilized to collect reviews for noun phrase chunking.  Link to the main user review page for each of the three movies are shown below.  To assure both positive and negative reviews are collected, there are two links per movie.  One is sorted descending by user rating.  The other is sorted ascending by user rating.  Both links have "spoiler alert" messages suppressed as these reviews are often more akin to a summarization of the movie plot instead of a true review.

# %%
#Rocky movie list.  Two links for each movie to assure positive and negative reviews are captured.  
#Sort descending by Review Rating.  Sort ascending by Review Rating.

#Rocky
rockyDict = {"aRocky":"https://www.imdb.com/title/tt0075148/reviews?spoiler=hide&sort=userRating&dir=asc&ratingFilter=0", 
         "dRocky":"https://www.imdb.com/title/tt0075148/reviews?spoiler=hide&sort=userRating&dir=desc&ratingFilter=0", 
#Rocky 2
         "dRocky 2":"https://www.imdb.com/title/tt0079817/reviews?spoiler=hide&sort=userRating&dir=desc&ratingFilter=0",
         "aRocky 2":"https://www.imdb.com/title/tt0079817/reviews?spoiler=hide&sort=userRating&dir=asc&ratingFilter=0",
#Rocky 3
         "dRocky 3":"https://www.imdb.com/title/tt0084602/reviews?spoiler=hide&sort=userRating&dir=desc&ratingFilter=0",
         "aRocky 3":"https://www.imdb.com/title/tt0084602/reviews?spoiler=hide&sort=userRating&dir=asc&ratingFilter=0"
            }

rockyKeys = rockyDict.keys()

# %% [markdown]
# The individual links to the user reviews are collected below.  A get request uses each of the links in the "rockyDict" python dictionary.  The response is parsed by Beautiful Soup to find the individual links to each individual review.  The review URLs along with the movie name are written to a dataframe named dfRockyReviews.

# %%
reviewUrls = list()
dfRockyReviews = pd.DataFrame(columns = ['Movie', 'ReviewURL'])

for r in rockyKeys:
    #print(r, rockyDict[r])
    response = requests.get(rockyDict[r])
    soup = BeautifulSoup(response.text, 'html.parser')
    rUrls = ["http:" + s.attrs['href'] for s in soup.find_all(href = True, class_ = 'title')]
    reviewUrls = reviewUrls + rUrls
    for u in rUrls:
        dfRockyReviews = dfRockyReviews.append({'Movie':r[1:], 'ReviewURL':u}, ignore_index=True)

# %% [markdown]
# A sample of the dfRockyReviews dataframe is shown below.

# %%
dfRockyReviews[0:5]
# Out:
#    Movie                            ReviewURL
# 0  Rocky  http:/review/rw0149538/?ref_=tt_urv
# 1  Rocky  http:/review/rw4247059/?ref_=tt_urv
# 2  Rocky  http:/review/rw0149534/?ref_=tt_urv
# 3  Rocky  http:/review/rw3647093/?ref_=tt_urv
# 4  Rocky  http:/review/rw2406266/?ref_=tt_urv

# %% [markdown]
# #### 5.2
# The individual review URLs collected above will be requested and parsed to retrieve key qualitative and categorical data about each review along with the review text itself.  These details are stored in a new dataframe named dfReviewDetails.  The first five records are this dataframe are shown below.

# %% [markdown]
# rjson
# {'@context': 'http://schema.org',
#  '@type': 'Review',
#  'itemReviewed': {'@type': 'CreativeWork', 'url': '/title/tt0075148/'},
#  'author': {'@type': 'Person', 'name': 'drew-104'},
#  'dateCreated': '1999-11-25',
#  'inLanguage': 'English',
#  'name': 'Dumbest, Most Cornball Film Ever Made',
#  'reviewBody': 'I still remember my initial outrage that this piece of sentimental slop was even made. As unrealistic as they get, this movie included so many cliches, stupidities, and bad acting that it proves for all time just how ignorant Hollywood and the movie-going public really are.',
#  'reviewRating': {'@type': 'Rating',
#   'worstRating': '1',
#   'bestRating': '10',
#   'ratingValue': '1'}}

# %%
dfReviewDetails = pd.DataFrame(columns=['Movie', 'ReviewUrl', 'ReviewDate', 'ReviewTitle', 'Review', 'Rating', 
                                        'Language'])
counter = 0

for r in reviewUrls:
    fullUrl = "https://www.imdb.com" + r[5:]
    response2 = requests.get(fullUrl)
    soup2 = BeautifulSoup(response2.text, 'html.parser')
    rjson = soup2.find('script', type = 'application/ld+json').text
    rjson = json.loads(rjson)
    
    try:
        rating = rjson['reviewRating']['ratingValue']
    except Exception as e:
        #print("No User Rating")
        rating = 5
    
    dfReviewDetails = dfReviewDetails.append({'Movie':dfRockyReviews.Movie[counter], 'ReviewUrl':r, 
                                              'ReviewDate':rjson['dateCreated'], 'ReviewTitle':rjson['name'], 
                                              'Review':rjson['reviewBody'], 'Rating':rating, 
                                              'Language':rjson['inLanguage']}, ignore_index=True)
    counter += 1

dfReviewDetails[0:5]
# Out:
#    Movie                            ReviewUrl  ReviewDate  \
# 0  Rocky  http:/review/rw0149538/?ref_=tt_urv  1999-11-25
# 1  Rocky  http:/review/rw4247059/?ref_=tt_urv  2018-07-21
# 2  Rocky  http:/review/rw0149534/?ref_=tt_urv  1998-08-19
# 3  Rocky  http:/review/rw3647093/?ref_=tt_urv  2017-02-24
# 4  Rocky  http:/review/rw2406266/?ref_=tt_urv  2011-03-30
#
#                                          ReviewTitle  \
# 0              Dumbest, Most Cornball Film Ever Made
# 1                                            Rubbish
# 2                          overrated piece of cheese
# 3                              Eh....it was alright.
# 4  I can't believe the script was made into a mov...
#
#                                               Review Rating Language
# 0  I still remember my initial outrage that this ...      1  English
# 1  The fight scenes are pathetic and the acting i...      1  English
# 2  grubby late-night fare achieved way too much s...      2  English
# 3  I didn't particularly like this movie. Dimwitt...      3  English
# 4  I was told by many that Rocky is a beautiful m...      3  English

# %% [markdown]
# #### 5.3 - Spacy Chunking
# Question 5.3 requires a list of noun phrase chunks from each sentence in the movie reviews collected above.  Though the request is for a single list of noun phrase chunks, the results from both Spacy and Pattern chunking are shown below.  First, the Spacy chunks are generated.  The results of the Spacy chunker are impressive.  Visual examination of the results shown proper nouns are mostly handled accurately, and the noun phrases are accurately identified.  Futhermore, the process takes under three minutes are a modestly powered machine.  The chunk labels, which should be restricted to "NP" (noun phrase), noun phrase texts and the chunk roots are displayed for each chunk.

# %%
# %%time

for r, m, t in zip(dfReviewDetails.Review, dfReviewDetails.Movie, dfReviewDetails.ReviewTitle):
    #Spacy Chunking
    doc = nlp(r)
    print("===================================================================================")
    print("===  Movie:", m, "Review Title:", t)
    print("===================================================================================")
    for chunk in doc.noun_chunks:
        print(chunk.label_, "|| Text:", chunk.text, "|| Phrase Root:", chunk.root.text)
    print("===================================================================================")
    print("=================================== End Review ====================================")
    print("===================================================================================")
# Out:
# ===================================================================================
# ===  Movie: Rocky Review Title: Dumbest, Most Cornball Film Ever Made
# ===================================================================================
# NP || Text: I || Phrase Root: I
# NP || Text: my initial outrage || Phrase Root: outrage
# NP || Text: this piece || Phrase Root: piece
# NP || Text: sentimental slop || Phrase Root: slop
# NP || Text: they || Phrase Root: they
# NP || Text: this movie || Phrase Root: movie
# NP || Text: so many cliches || Phrase Root: cliches
# NP || Text: stupidities || Phrase Root: stupidities
# NP || Text: it || Phrase Root: it
# NP || Text: all time || Phrase Root: time
# NP || Text: just how ignorant Hollywood || Phrase Root: Hollywood
# NP || Text: the movie-going public || Phrase Root: public
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: Rubbish
# ===================================================================================
# NP || Text: The fight scenes || Phrase Root: scenes
# NP || Text: the acting || Phrase Root: acting
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: overrated piece of cheese
# ===================================================================================
# NP || Text: grubby late-night fare || Phrase Root: fare
# NP || Text: way too much success || Phrase Root: success
# NP || Text: a primitive story || Phrase Root: story
# NP || Text: A silly promotional song || Phrase Root: song
# NP || Text: laughable script || Phrase Root: script
# NP || Text: performances || Phrase Root: performances
# NP || Text: I || Phrase Root: I
# NP || Text: no clue || Phrase Root: clue
# NP || Text: this picture || Phrase Root: picture
# NP || Text: its heart || Phrase Root: heart
# NP || Text: its sleeve || Phrase Root: sleeve
# NP || Text: the critcal appreciation || Phrase Root: appreciation
# NP || Text: it || Phrase Root: it
# NP || Text: This high -concept film || Phrase Root: film
# NP || Text: it || Phrase Root: it
# NP || Text: the wave || Phrase Root: wave
# NP || Text: no -brain feel-good fare || Phrase Root: fare
# NP || Text: the eighties || Phrase Root: eighties
# NP || Text: the present || Phrase Root: present
# NP || Text: It || Phrase Root: It
# NP || Text: a boxing champ || Phrase Root: champ
# NP || Text: Apollo Creed || Phrase Root: Creed
# NP || Text: the bout || Phrase Root: bout
# NP || Text: the audience || Phrase Root: audience
# NP || Text: this idiot || Phrase Root: idiot
# NP || Text: the ring || Phrase Root: ring
# NP || Text: who || Phrase Root: who
# NP || Text: a razor blade || Phrase Root: blade
# NP || Text: he || Phrase Root: he
# NP || Text: I || Phrase Root: I
# NP || Text: the sequels || Phrase Root: sequels
# NP || Text: Aki Kaurismaki || Phrase Root: Kaurismaki
# NP || Text: Rocky VI || Phrase Root: VI
# NP || Text: _ || Phrase Root: _
# NP || Text: even more laugh || Phrase Root: laugh
# NP || Text: this film || Phrase Root: film
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: Eh....it was alright.
# ===================================================================================
# NP || Text: I || Phrase Root: I
# NP || Text: this movie || Phrase Root: movie
# NP || Text: Dimwitted athletes || Phrase Root: athletes
# NP || Text: me || Phrase Root: me
# NP || Text: I || Phrase Root: I
# NP || Text: it || Phrase Root: it
# NP || Text: no accounting || Phrase Root: accounting
# NP || Text: the public's taste || Phrase Root: taste
# NP || Text: I || Phrase Root: I
# NP || Text: most sports movies || Phrase Root: movies
# NP || Text: I || Phrase Root: I
# NP || Text: a pure sports movie || Phrase Root: movie
# NP || Text: I || Phrase Root: I
# NP || Text: it || Phrase Root: it
# NP || Text: The music || Phrase Root: music
# NP || Text: me || Phrase Root: me
# NP || Text: I || Phrase Root: I
# NP || Text: they || Phrase Root: they
# NP || Text: that annoying music || Phrase Root: music
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: I can't believe the script was made into a movie...
# ===================================================================================
# NP || Text: I || Phrase Root: I
# NP || Text: Rocky || Phrase Root: Rocky
# NP || Text: a beautiful movie || Phrase Root: movie
# NP || Text: I || Phrase Root: I
# NP || Text: I || Phrase Root: I
# NP || Text: The movie || Phrase Root: movie
# NP || Text: the same annoyingly slow pace || Phrase Root: pace
# NP || Text: the clichéd characters || Phrase Root: characters
# NP || Text: Stalone || Phrase Root: Stalone
# NP || Text: the plot || Phrase Root: plot
# NP || Text: I || Phrase Root: I
# NP || Text: you || Phrase Root: you
# NP || Text: the end || Phrase Root: end
# NP || Text: your eyes || Phrase Root: eyes
# NP || Text: you || Phrase Root: you
# NP || Text: grass || Phrase Root: grass
# NP || Text: this movie || Phrase Root: movie
# NP || Text: you || Phrase Root: you
# NP || Text: a story || Phrase Root: story
# NP || Text: intellect || Phrase Root: intellect
# NP || Text: you || Phrase Root: you
# NP || Text: the plot gripping || Phrase Root: gripping
# NP || Text: I || Phrase Root: I
# NP || Text: it || Phrase Root: it
# NP || Text: I || Phrase Root: I
# NP || Text: my time || Phrase Root: time
# NP || Text: It || Phrase Root: It
# NP || Text: I || Phrase Root: I
# NP || Text: this mind || Phrase Root: mind
# NP || Text: numbing movie || Phrase Root: movie
# NP || Text: anyone || Phrase Root: anyone
# NP || Text: I || Phrase Root: I
# NP || Text: them || Phrase Root: them
# NP || Text: my friends || Phrase Root: friends
# NP || Text: me || Phrase Root: me
# NP || Text: it || Phrase Root: it
# NP || Text: a practical joke || Phrase Root: joke
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: The most overrated movie of all time
# ===================================================================================
# NP || Text: I || Phrase Root: I
# NP || Text: this movie || Phrase Root: movie
# NP || Text: it || Phrase Root: it
# NP || Text: I || Phrase Root: I
# NP || Text: Sylvester Stallone || Phrase Root: Stallone
# NP || Text: no expectations || Phrase Root: expectations
# NP || Text: preconceptions || Phrase Root: preconceptions
# NP || Text: it || Phrase Root: it
# NP || Text: a good depiction || Phrase Root: depiction
# NP || Text: boxing || Phrase Root: boxing
# NP || Text: I || Phrase Root: I
# NP || Text: it || Phrase Root: it
# NP || Text: I || Phrase Root: I
# NP || Text: the theater || Phrase Root: theater
# NP || Text: I || Phrase Root: I
# NP || Text: it || Phrase Root: it
# NP || Text: The film || Phrase Root: film
# NP || Text: sappiest pieces || Phrase Root: pieces
# NP || Text: melodramatic tripe || Phrase Root: tripe
# NP || Text: I || Phrase Root: I
# NP || Text: Every character || Phrase Root: character
# NP || Text: a stereotype || Phrase Root: stereotype
# NP || Text: every turn || Phrase Root: turn
# NP || Text: amateurish plot || Phrase Root: plot
# NP || Text: the boxing || Phrase Root: boxing
# NP || Text: a Popeye cartoon || Phrase Root: cartoon
# NP || Text: more realistic action || Phrase Root: action
# NP || Text: It || Phrase Root: It
# NP || Text: the most ludicrous exhibitions || Phrase Root: exhibitions
# NP || Text: professional wrestling matches || Phrase Root: matches
# NP || Text: any combatant || Phrase Root: combatant
# NP || Text: who || Phrase Root: who
# NP || Text: two minutes || Phrase Root: minutes
# NP || Text: the kind || Phrase Root: kind
# NP || Text: pummeling || Phrase Root: pummeling
# NP || Text: the title fight || Phrase Root: fight
# NP || Text: brain || Phrase Root: brain
# NP || Text: My contempt || Phrase Root: contempt
# NP || Text: this trash || Phrase Root: trash
# NP || Text: even greater depths || Phrase Root: depths
# NP || Text: I || Phrase Root: I
# NP || Text: it || Phrase Root: it
# NP || Text: three outstanding movies || Phrase Root: movies
# NP || Text: Network || Phrase Root: Network
# NP || Text: Taxi Driver || Phrase Root: Driver
# NP || Text: All the President's Men || Phrase Root: Men
# NP || Text: the best picture || Phrase Root: picture
# NP || Text: Oscar || Phrase Root: Oscar
# NP || Text: I || Phrase Root: I
# NP || Text: Bound || Phrase Root: Bound
# NP || Text: Glory || Phrase Root: Glory
# NP || Text: I || Phrase Root: I
# NP || Text: no doubt || Phrase Root: doubt
# NP || Text: it || Phrase Root: it
# NP || Text: a far better movie || Phrase Root: movie
# NP || Text: this drivel || Phrase Root: drivel
# NP || Text: I || Phrase Root: I
# NP || Text: a portion || Phrase Root: portion
# NP || Text: the public || Phrase Root: public
# NP || Text: Rocky || Phrase Root: Rocky
# NP || Text: I || Phrase Root: I
# NP || Text: no excuse || Phrase Root: excuse
# NP || Text: the voting || Phrase Root: voting
# NP || Text: the Academy members || Phrase Root: members
# NP || Text: Shame || Phrase Root: Shame
# NP || Text: them || Phrase Root: them
# NP || Text: this sorry excuse || Phrase Root: excuse
# NP || Text: a movie || Phrase Root: movie
# NP || Text: such worthy contenders || Phrase Root: contenders
# NP || Text: It || Phrase Root: It
# NP || Text: about as much sense || Phrase Root: sense
# NP || Text: a punch-drunk bar-fighting buffoon || Phrase Root: buffoon
# NP || Text: a title || Phrase Root: title
# NP || Text: Muhammad Ali || Phrase Root: Ali
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: Hate me if you want but I didn't like this film
# ===================================================================================
# NP || Text: I || Phrase Root: I
# NP || Text: it || Phrase Root: it
# NP || Text: I || Phrase Root: I
# NP || Text: this film || Phrase Root: film
# NP || Text: I || Phrase Root: I
# NP || Text: me || Phrase Root: me
# NP || Text: it || Phrase Root: it
# NP || Text: the truth || Phrase Root: truth
# NP || Text: I || Phrase Root: I
# NP || Text: any interest || Phrase Root: interest
# NP || Text: boxing || Phrase Root: boxing
# NP || Text: the film's content || Phrase Root: content
# NP || Text: Rocky's struggle || Phrase Root: struggle
# NP || Text: me || Phrase Root: me
# NP || Text: it || Phrase Root: it
# NP || Text: I || Phrase Root: I
# NP || Text: Stallone's portrayal || Phrase Root: portrayal
# NP || Text: Rocky || Phrase Root: Rocky
# NP || Text: his shouting || Phrase Root: shouting
# NP || Text: I || Phrase Root: I
# NP || Text: anything || Phrase Root: anything
# NP || Text: he || Phrase Root: he
# NP || Text: me || Phrase Root: me
# NP || Text: the character || Phrase Root: character
# NP || Text: Although all credit || Phrase Root: credit
# NP || Text: the set-designers || Phrase Root: designers
# NP || Text: Rocky's apartment || Phrase Root: apartment
# NP || Text: a horrible place || Phrase Root: place
# NP || Text: the peeling wallpaper || Phrase Root: wallpaper
# NP || Text: God || Phrase Root: God
# NP || Text: Burgess Meredith || Phrase Root: Meredith
# NP || Text: it || Phrase Root: it
# NP || Text: my full review || Phrase Root: review
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: Vastly overrated
# ===================================================================================
# NP || Text: the Best Picture Oscar || Phrase Root: Oscar
# NP || Text: Story || Phrase Root: Story
# NP || Text: spells || Phrase Root: spells
# NP || Text: The opening setup || Phrase Root: setup
# NP || Text: it || Phrase Root: it
# NP || Text: a picture || Phrase Root: picture
# NP || Text: a man || Phrase Root: man
# NP || Text: a dead-end situation || Phrase Root: situation
# NP || Text: you || Phrase Root: you
# NP || Text: the movie || Phrase Root: movie
# NP || Text: he || Phrase Root: he
# NP || Text: himself || Phrase Root: himself
# NP || Text: that situation || Phrase Root: situation
# NP || Text: it || Phrase Root: it
# NP || Text: it || Phrase Root: it
# NP || Text: a lottery || Phrase Root: lottery
# NP || Text: hard work || Phrase Root: work
# NP || Text: The only thing || Phrase Root: thing
# NP || Text: it || Phrase Root: it
# NP || Text: the fight scene || Phrase Root: scene
# NP || Text: the end || Phrase Root: end
# NP || Text: The Rocky-Adrian relationship || Phrase Root: relationship
# NP || Text: insult || Phrase Root: insult
# NP || Text: injury || Phrase Root: injury
# NP || Text: Sylvester Stallone || Phrase Root: Stallone
# NP || Text: a Best Actor Oscar nomination || Phrase Root: nomination
# NP || Text: his series || Phrase Root: series
# NP || Text: monosyllabic grunts || Phrase Root: grunts
# NP || Text: dialogue || Phrase Root: dialogue
# NP || Text: total Rocky || Phrase Root: Rocky
# NP || Text: three Academy awards || Phrase Root: awards
# NP || Text: seven other nominations || Phrase Root: nominations
# NP || Text: only the nomination || Phrase Root: nomination
# NP || Text: Best Original Song || Phrase Root: Song
# NP || Text: the most over-rated and over-awarded films || Phrase Root: films
# NP || Text: history || Phrase Root: history
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: A screaming movie with some boxing undertones
# ===================================================================================
# NP || Text: It || Phrase Root: It
# NP || Text: a long time || Phrase Root: time
# NP || Text: I || Phrase Root: I
# NP || Text: it || Phrase Root: it
# NP || Text: I || Phrase Root: I
# NP || Text: it || Phrase Root: it
# NP || Text: a movie || Phrase Root: movie
# NP || Text: boxing || Phrase Root: boxing
# NP || Text: an underdog || Phrase Root: underdog
# NP || Text: who || Phrase Root: who
# NP || Text: a chance || Phrase Root: chance
# NP || Text: it || Phrase Root: it
# NP || Text: I || Phrase Root: I
# NP || Text: it || Phrase Root: it
# NP || Text: I || Phrase Root: I
# NP || Text: it || Phrase Root: it
# NP || Text: fact || Phrase Root: fact
# NP || Text: a movie || Phrase Root: movie
# NP || Text: the dangers || Phrase Root: dangers
# NP || Text: brain damage || Phrase Root: damage
# NP || Text: Every single person || Phrase Root: person
# NP || Text: this movie || Phrase Root: movie
# NP || Text: the boxers || Phrase Root: boxers
# NP || Text: trainers || Phrase Root: trainers
# NP || Text: the ice rink janitor || Phrase Root: janitor
# NP || Text: half-wit || Phrase Root: wit
# NP || Text: a couple || Phrase Root: couple
# NP || Text: different ways || Phrase Root: ways
# NP || Text: the way || Phrase Root: way
# NP || Text: people || Phrase Root: people
# NP || Text: people || Phrase Root: people
# NP || Text: Everything || Phrase Root: Everything
# NP || Text: a screaming match || Phrase Root: match
# NP || Text: It || Phrase Root: It
# NP || Text: Many parts || Phrase Root: parts
# NP || Text: the movie || Phrase Root: movie
# NP || Text: The premise || Phrase Root: premise
# NP || Text: itself || Phrase Root: itself
# NP || Text: The boxing parts || Phrase Root: parts
# NP || Text: it || Phrase Root: it
# NP || Text: us || Phrase Root: us
# NP || Text: who || Phrase Root: who
# NP || Text: it || Phrase Root: it
# NP || Text: All other things || Phrase Root: things
# NP || Text: first hour || Phrase Root: hour
# NP || Text: the movie || Phrase Root: movie
# NP || Text: the rest || Phrase Root: rest
# NP || Text: you || Phrase Root: you
# NP || Text: the screaming || Phrase Root: screaming
# NP || Text: it || Phrase Root: it
# NP || Text: it || Phrase Root: it
# NP || Text: it || Phrase Root: it
# NP || Text: you || Phrase Root: you
# NP || Text: An iconic movie || Phrase Root: movie
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: it's a man's romance.
# ===================================================================================
# NP || Text: one our two fight scenes || Phrase Root: scenes
# NP || Text: it || Phrase Root: it
# NP || Text: a romance || Phrase Root: romance
# NP || Text: O.k || Phrase Root: O.k
# NP || Text: Sylvester Stallone || Phrase Root: Stallone
# NP || Text: the star || Phrase Root: star
# NP || Text: this movie || Phrase Root: movie
# NP || Text: he || Phrase Root: he
# NP || Text: a t.u.f guy || Phrase Root: guy
# NP || Text: it || Phrase Root: it
# NP || Text: him || Phrase Root: him
# NP || Text: his girl friend || Phrase Root: friend
# NP || Text: Sylvester Stallone || Phrase Root: Stallone
# NP || Text: star || Phrase Root: star
# NP || Text: this movie || Phrase Root: movie
# NP || Text: a romance movie || Phrase Root: movie
# NP || Text: men || Phrase Root: men
# NP || Text: Rocky II || Phrase Root: II
# NP || Text: Rocky II || Phrase Root: II
# NP || Text: It || Phrase Root: It
# NP || Text: this one || Phrase Root: one
# NP || Text: It || Phrase Root: It
# NP || Text: Rocky III || Phrase Root: III
# NP || Text: Rocky III || Phrase Root: III
# NP || Text: Rocky III || Phrase Root: III
# NP || Text: this one || Phrase Root: one
# NP || Text: hype || Phrase Root: hype
# NP || Text: It || Phrase Root: It
# NP || Text: action movie || Phrase Root: movie
# NP || Text: It || Phrase Root: It
# NP || Text: a man's romance || Phrase Root: romance
# NP || Text: many romance movies || Phrase Root: movies
# NP || Text: Overrated overrated overrated hype hype hype || Phrase Root: hype
# NP || Text: And no action || Phrase Root: action
# NP || Text: Sports || Phrase Root: Sports
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: an iconic film
# ===================================================================================
# NP || Text: Rocky || Phrase Root: Rocky
# NP || Text: a film || Phrase Root: film
# NP || Text: a boxer || Phrase Root: boxer
# NP || Text: who || Phrase Root: who
# NP || Text: ultimate levels || Phrase Root: levels
# NP || Text: a champion || Phrase Root: champion
# NP || Text: the ring || Phrase Root: ring
# NP || Text: the way || Phrase Root: way
# NP || Text: he || Phrase Root: he
# NP || Text: confidence || Phrase Root: confidence
# NP || Text: a young woman || Phrase Root: woman
# NP || Text: who || Phrase Root: who
# NP || Text: him || Phrase Root: him
# NP || Text: the strength || Phrase Root: strength
# NP || Text: he || Phrase Root: he
# NP || Text: a story || Phrase Root: story
# NP || Text: endurance || Phrase Root: endurance
# NP || Text: love || Phrase Root: love
# NP || Text: it || Phrase Root: it
# NP || Text: the most quoted films || Phrase Root: films
# NP || Text: all time || Phrase Root: time
# NP || Text: the line 'Yo, Adrian || Phrase Root: Adrian
# NP || Text: I || Phrase Root: I
# NP || Text: it || Phrase Root: it
# NP || Text: the famous clips || Phrase Root: clips
# NP || Text: Rocky || Phrase Root: Rocky
# NP || Text: exercise || Phrase Root: exercise
# NP || Text: his endurance || Phrase Root: endurance
# NP || Text: the Rocky theme || Phrase Root: theme
# NP || Text: The story || Phrase Root: story
# NP || Text: those moments || Phrase Root: moments
# NP || Text: Not a bad film || Phrase Root: film
# NP || Text: it || Phrase Root: it
# NP || Text: a good choice || Phrase Root: choice
# NP || Text: music || Phrase Root: music
# NP || Text: you || Phrase Root: you
# NP || Text: a sense || Phrase Root: sense
# NP || Text: hope || Phrase Root: hope
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: Good to watch
# ===================================================================================
# NP || Text: This movie || Phrase Root: movie
# NP || Text: I || Phrase Root: I
# NP || Text: it || Phrase Root: it
# NP || Text: parts || Phrase Root: parts
# NP || Text: Who || Phrase Root: Who
# NP || Text: your love life || Phrase Root: life
# NP || Text: I || Phrase Root: I
# NP || Text: the fight || Phrase Root: fight
# NP || Text: More fight || Phrase Root: fight
# NP || Text: less romancing || Phrase Root: romancing
# NP || Text: Lets || Phrase Root: Lets
# NP || Text: Rocky || Phrase Root: Rocky
# NP || Text: us || Phrase Root: us
# NP || Text: your love life || Phrase Root: life
# NP || Text: We || Phrase Root: We
# NP || Text: Grade || Phrase Root: Grade
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: Builds character rather than spectacle, but isn't quite as gripping as you'd expect.
# ===================================================================================
# NP || Text: a low-budget || Phrase Root: budget
# NP || Text: a chance' type film || Phrase Root: film
# NP || Text: pretty accomplished and realistic stuff || Phrase Root: stuff
# NP || Text: its focus || Phrase Root: focus
# NP || Text: character || Phrase Root: character
# NP || Text: an empathetic underdog || Phrase Root: underdog
# NP || Text: overt spectacle || Phrase Root: spectacle
# NP || Text: something || Phrase Root: something
# NP || Text: the sequels || Phrase Root: sequels
# NP || Text: it || Phrase Root: it
# NP || Text: the point || Phrase Root: point
# NP || Text: the final bout || Phrase Root: bout
# NP || Text: the piece's highlights || Phrase Root: highlights
# NP || Text: a hit || Phrase Root: hit
# NP || Text: a big issue || Phrase Root: issue
# NP || Text: the flick || Phrase Root: flick
# NP || Text: the fact || Phrase Root: fact
# NP || Text: the preceding film || Phrase Root: film
# NP || Text: a bit || Phrase Root: bit
# NP || Text: a drag || Phrase Root: drag
# NP || Text: Stallone's dialogue || Phrase Root: dialogue
# NP || Text: a problem || Phrase Root: problem
# NP || Text: It || Phrase Root: It
# NP || Text: any stretch || Phrase Root: stretch
# NP || Text: it || Phrase Root: it
# NP || Text: it || Phrase Root: it
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: I Don't Get It
# ===================================================================================
# NP || Text: I || Phrase Root: I
# NP || Text: Rocky || Phrase Root: Rocky
# NP || Text: the first time || Phrase Root: time
# NP || Text: guilt || Phrase Root: guilt
# NP || Text: it || Phrase Root: it
# NP || Text: It || Phrase Root: It
# NP || Text: the other great films || Phrase Root: films
# NP || Text: the 1970s || Phrase Root: 1970s
# NP || Text: film history || Phrase Root: history
# NP || Text: I || Phrase Root: I
# NP || Text: I || Phrase Root: I
# NP || Text: something || Phrase Root: something
# NP || Text: I || Phrase Root: I
# NP || Text: I || Phrase Root: I
# NP || Text: it || Phrase Root: it
# NP || Text: What || Phrase Root: What
# NP || Text: the-challenge || Phrase Root: challenge
# NP || Text: me || Phrase Root: me
# NP || Text: It || Phrase Root: It
# NP || Text: a fine little movie || Phrase Root: movie
# NP || Text: I || Phrase Root: I
# NP || Text: what || Phrase Root: what
# NP || Text: it || Phrase Root: it
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: My dad forced me to watch it
# ===================================================================================
# NP || Text: my father || Phrase Root: father
# NP || Text: us || Phrase Root: us
# NP || Text: the movie || Phrase Root: movie
# NP || Text: we || Phrase Root: we
# NP || Text: He || Phrase Root: He
# NP || Text: it || Phrase Root: it
# NP || Text: his mind || Phrase Root: mind
# NP || Text: it || Phrase Root: it
# NP || Text: It || Phrase Root: It
# NP || Text: the suspense || Phrase Root: suspense
# NP || Text: the camera || Phrase Root: camera
# NP || Text: nice pictures || Phrase Root: pictures
# NP || Text: also the background story || Phrase Root: story
# NP || Text: Sylvester Stallone || Phrase Root: Stallone
# NP || Text: the studios || Phrase Root: studios
# NP || Text: his film || Phrase Root: film
# NP || Text: conclusion || Phrase Root: conclusion
# NP || Text: 16 years || Phrase Root: years
# NP || Text: it || Phrase Root: it
# NP || Text: the picture quality || Phrase Root: quality
# NP || Text: the background story || Phrase Root: story
# NP || Text: The story || Phrase Root: story
# NP || Text: you || Phrase Root: you
# NP || Text: the film || Phrase Root: film
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: Popular melodrama in a landmark era for American cinema
# ===================================================================================
# NP || Text: A landmark year || Phrase Root: year
# NP || Text: cinema || Phrase Root: cinema
# NP || Text: the most heavily contested Academy awards || Phrase Root: awards
# NP || Text: history || Phrase Root: history
# NP || Text: you || Phrase Root: you
# NP || Text: it || Phrase Root: it
# NP || Text: the 70s || Phrase Root: 70s
# NP || Text: the greatest time || Phrase Root: time
# NP || Text: American cinema || Phrase Root: cinema
# NP || Text: Scorsese || Phrase Root: Scorsese
# NP || Text: Coppola || Phrase Root: Coppola
# NP || Text: Lumet || Phrase Root: Lumet
# NP || Text: the fiercest battles || Phrase Root: battles
# NP || Text: the Academy awards || Phrase Root: awards
# NP || Text: it || Phrase Root: it
# NP || Text: an exciting time || Phrase Root: time
# NP || Text: moviegoers || Phrase Root: moviegoers
# NP || Text: Rocky || Phrase Root: Rocky
# NP || Text: a bad rap || Phrase Root: rap
# NP || Text: these American classics || Phrase Root: classics
# NP || Text: the prize || Phrase Root: prize
# NP || Text: the fact || Phrase Root: fact
# NP || Text: it || Phrase Root: it
# NP || Text: a powerful, inspirational film || Phrase Root: film
# NP || Text: a man's dreams || Phrase Root: dreams
# NP || Text: what || Phrase Root: what
# NP || Text: obstacles || Phrase Root: obstacles
# NP || Text: his way || Phrase Root: way
# NP || Text: The question || Phrase Root: question
# NP || Text: it || Phrase Root: it
# NP || Text: over 30 years || Phrase Root: years
# NP || Text: The character || Phrase Root: character
# NP || Text: Rocky || Phrase Root: Rocky
# NP || Text: the most memorable film characters || Phrase Root: characters
# NP || Text: Stallone || Phrase Root: Stallone
# NP || Text: a serious filmmaker || Phrase Root: filmmaker
# NP || Text: the sequences || Phrase Root: sequences
# NP || Text: film || Phrase Root: film
# NP || Text: popular culture || Phrase Root: culture
# NP || Text: fans || Phrase Root: fans
# NP || Text: these scenes || Phrase Root: scenes
# NP || Text: great emotional instability || Phrase Root: instability
# NP || Text: they || Phrase Root: they
# NP || Text: the greatest underdog stories || Phrase Root: stories
# NP || Text: Stallone || Phrase Root: Stallone
# NP || Text: the film || Phrase Root: film
# NP || Text: it's duration - no other actor || Phrase Root: actor
# NP || Text: Rocky || Phrase Root: Rocky
# NP || Text: The character || Phrase Root: character
# NP || Text: Stallone || Phrase Root: Stallone
# NP || Text: who || Phrase Root: who
# NP || Text: the screenplay || Phrase Root: screenplay
# NP || Text: Oscar || Phrase Root: Oscar
# NP || Text: both his acting || Phrase Root: acting
# NP || Text: writing || Phrase Root: writing
# NP || Text: Stallone's mannerisms || Phrase Root: mannerisms
# NP || Text: raw, dopey acting style || Phrase Root: style
# NP || Text: the character || Phrase Root: character
# NP || Text: a glove || Phrase Root: glove
# NP || Text: The writing || Phrase Root: writing
# NP || Text: I || Phrase Root: I
# NP || Text: some pacing issues || Phrase Root: issues
# NP || Text: the film || Phrase Root: film
# NP || Text: You || Phrase Root: You
# NP || Text: Stallone || Phrase Root: Stallone
# NP || Text: himself || Phrase Root: himself
# NP || Text: he || Phrase Root: he
# NP || Text: a good job || Phrase Root: job
# NP || Text: The other strength || Phrase Root: strength
# NP || Text: the film || Phrase Root: film
# NP || Text: the directing || Phrase Root: directing
# NP || Text: it || Phrase Root: it
# NP || Text: an Oscar || Phrase Root: Oscar
# NP || Text: It || Phrase Root: It
# NP || Text: The shades || Phrase Root: shades
# NP || Text: a dream || Phrase Root: dream
# NP || Text: light || Phrase Root: light
# NP || Text: The pacing || Phrase Root: pacing
# NP || Text: a orthodox story || Phrase Root: story
# NP || Text: favour || Phrase Root: favour
# NP || Text: the director || Phrase Root: director
# NP || Text: I || Phrase Root: I
# NP || Text: this film || Phrase Root: film
# NP || Text: I || Phrase Root: I
# NP || Text: the story || Phrase Root: story
# NP || Text: light || Phrase Root: light
# NP || Text: it || Phrase Root: it
# NP || Text: release || Phrase Root: release
# NP || Text: hindsight || Phrase Root: hindsight
# NP || Text: more recent boxing films || Phrase Root: films
# NP || Text: some dead moments || Phrase Root: moments
# NP || Text: I || Phrase Root: I
# NP || Text: the fight || Phrase Root: fight
# NP || Text: Rocky's soap operatic antics || Phrase Root: antics
# NP || Text: his girlfriend || Phrase Root: girlfriend
# NP || Text: family || Phrase Root: family
# NP || Text: the end || Phrase Root: end
# NP || Text: I || Phrase Root: I
# NP || Text: it || Phrase Root: it
# NP || Text: me || Phrase Root: me
# NP || Text: I || Phrase Root: I
# NP || Text: it || Phrase Root: it
# NP || Text: story || Phrase Root: story
# NP || Text: it || Phrase Root: it
# NP || Text: the other American films || Phrase Root: films
# NP || Text: this era || Phrase Root: era
# NP || Text: a comment || Phrase Root: comment
# NP || Text: American life || Phrase Root: life
# NP || Text: the dream || Phrase Root: dream
# NP || Text: All the President's Men, Taxi Driver || Phrase Root: Driver
# NP || Text: Network || Phrase Root: Network
# NP || Text: Raging || Phrase Root: Raging
# NP || Text: Bull || Phrase Root: Bull
# NP || Text: All these films || Phrase Root: films
# NP || Text: something || Phrase Root: something
# NP || Text: hopes || Phrase Root: hopes
# NP || Text: dreams || Phrase Root: dreams
# NP || Text: ideals || Phrase Root: ideals
# NP || Text: Rocky || Phrase Root: Rocky
# NP || Text: the hearts || Phrase Root: hearts
# NP || Text: the viewers || Phrase Root: viewers
# NP || Text: it || Phrase Root: it
# NP || Text: contemporaries || Phrase Root: contemporaries
# NP || Text: today's world || Phrase Root: world
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: Schlocky
# ===================================================================================
# NP || Text: The most memorable moment || Phrase Root: moment
# NP || Text: Rocky || Phrase Root: Rocky
# NP || Text: the love-scene || Phrase Root: scene
# NP || Text: the otherwise fetid room || Phrase Root: room
# NP || Text: such clean passion || Phrase Root: passion
# NP || Text: it || Phrase Root: it
# NP || Text: all cardinal passions || Phrase Root: passions
# NP || Text: resists || Phrase Root: resists
# NP || Text: an act || Phrase Root: act
# NP || Text: slow excitement || Phrase Root: excitement
# NP || Text: Rocky || Phrase Root: Rocky
# NP || Text: love || Phrase Root: love
# NP || Text: each other's weaknesses || Phrase Root: weaknesses
# NP || Text: The problem || Phrase Root: problem
# NP || Text: the best scene || Phrase Root: scene
# NP || Text: the movie || Phrase Root: movie
# NP || Text: the 'action || Phrase Root: action
# NP || Text: the 'sport || Phrase Root: sport
# NP || Text: This kind || Phrase Root: kind
# NP || Text: movies || Phrase Root: movies
# NP || Text: Rocky || Phrase Root: Rocky
# NP || Text: me || Phrase Root: me
# NP || Text: just a sweet romance || Phrase Root: romance
# NP || Text: an action || Phrase Root: action
# NP || Text: an underdog story || Phrase Root: story
# NP || Text: It || Phrase Root: It
# NP || Text: Boxing Practice || Phrase Root: Practice
# NP || Text: Rule || Phrase Root: Rule
# NP || Text: six raw eggs Rule || Phrase Root: Rule
# NP || Text: a mile || Phrase Root: mile
# NP || Text: I || Phrase Root: I
# NP || Text: Million Dollar Baby || Phrase Root: Baby
# NP || Text: its guts || Phrase Root: guts
# NP || Text: mainly its balance || Phrase Root: balance
# NP || Text: action || Phrase Root: action
# NP || Text: drama || Phrase Root: drama
# NP || Text: The second half || Phrase Root: half
# NP || Text: I || Phrase Root: I
# NP || Text: it || Phrase Root: it
# NP || Text: the end || Phrase Root: end
# NP || Text: my eyes || Phrase Root: eyes
# NP || Text: Rocky || Phrase Root: Rocky
# NP || Text: such a film || Phrase Root: film
# NP || Text: it || Phrase Root: it
# NP || Text: maudlin || Phrase Root: maudlin
# NP || Text: pretense || Phrase Root: pretense
# NP || Text: The movie || Phrase Root: movie
# NP || Text: the 30s || Phrase Root: 30s
# NP || Text: I || Phrase Root: I
# NP || Text: the accent || Phrase Root: accent
# NP || Text: Or the caricature || Phrase Root: caricature
# NP || Text: the supporting cast || Phrase Root: cast
# NP || Text: The opening scene || Phrase Root: scene
# NP || Text: a normal boxing match || Phrase Root: match
# NP || Text: the brawny Stallone || Phrase Root: Stallone
# NP || Text: another unknown face || Phrase Root: face
# NP || Text: A small-time boxer || Phrase Root: boxer
# NP || Text: a collector || Phrase Root: collector
# NP || Text: a 'large-hearted' loan-shark named Gazzo || Phrase Root: Gazzo
# NP || Text: he || Phrase Root: he
# NP || Text: an ordinary life || Phrase Root: life
# NP || Text: his pets || Phrase Root: pets
# NP || Text: a painfully shy girl || Phrase Root: girl
# NP || Text: His preference || Phrase Root: preference
# NP || Text: the conversation || Phrase Root: conversation
# NP || Text: he || Phrase Root: he
# NP || Text: her || Phrase Root: her
# NP || Text: a foul-mouthed girl || Phrase Root: girl
# NP || Text: a "w**re || Phrase Root: w**re
# NP || Text: future || Phrase Root: future
# NP || Text: a lady || Phrase Root: lady
# NP || Text: his wife || Phrase Root: wife
# NP || Text: he || Phrase Root: he
# NP || Text: Adrian || Phrase Root: Adrian
# NP || Text: This small-timer || Phrase Root: timer
# NP || Text: a pedestal || Phrase Root: pedestal
# NP || Text: he || Phrase Root: he
# NP || Text: an opportunity || Phrase Root: opportunity
# NP || Text: the flamboyant, insidious, conceited world-champion Apollo Creed || Phrase Root: Creed
# NP || Text: who || Phrase Root: who
# NP || Text: a "good show || Phrase Root: show
# NP || Text: Sylvester || Phrase Root: Sylvester
# NP || Text: what || Phrase Root: what
# NP || Text: he || Phrase Root: he
# NP || Text: I || Phrase Root: I
# NP || Text: any vigor || Phrase Root: vigor
# NP || Text: his eyes || Phrase Root: eyes
# NP || Text: his eyes || Phrase Root: eyes
# NP || Text: the scene || Phrase Root: scene
# NP || Text: he || Phrase Root: he
# NP || Text: his frustration || Phrase Root: frustration
# NP || Text: his to-be trainer || Phrase Root: trainer
# NP || Text: faith || Phrase Root: faith
# NP || Text: him || Phrase Root: him
# NP || Text: he || Phrase Root: he
# NP || Text: the line || Phrase Root: line
# NP || Text: them || Phrase Root: them
# NP || Text: it || Phrase Root: it
# NP || Text: the garbled voice || Phrase Root: voice
# NP || Text: he || Phrase Root: he
# NP || Text: the script || Phrase Root: script
# NP || Text: humor || Phrase Root: humor
# NP || Text: love || Phrase Root: love
# NP || Text: it || Phrase Root: it
# NP || Text: the end || Phrase Root: end
# NP || Text: Sly || Phrase Root: Sly
# NP || Text: a screenwriter || Phrase Root: screenwriter
# NP || Text: The choreography || Phrase Root: choreography
# NP || Text: the boxing sequences || Phrase Root: sequences
# NP || Text: anything || Phrase Root: anything
# NP || Text: it || Phrase Root: it
# NP || Text: steam || Phrase Root: steam
# NP || Text: The climatic boxing scene || Phrase Root: scene
# NP || Text: Sly || Phrase Root: Sly
# NP || Text: professional help || Phrase Root: help
# NP || Text: these sequences || Phrase Root: sequences
# NP || Text: it || Phrase Root: it
# NP || Text: Talia || Phrase Root: Talia
# NP || Text: the highly introverted, taciturn girl-friend || Phrase Root: friend
# NP || Text: who || Phrase Root: who
# NP || Text: the scenes || Phrase Root: scenes
# NP || Text: I || Phrase Root: I
# NP || Text: her || Phrase Root: her
# NP || Text: I || Phrase Root: I
# NP || Text: myself || Phrase Root: myself
# NP || Text: a very introverted but caring person || Phrase Root: person
# NP || Text: who || Phrase Root: who
# NP || Text: bouts || Phrase Root: bouts
# NP || Text: hysterics || Phrase Root: hysterics
# NP || Text: The most captivating quality || Phrase Root: quality
# NP || Text: Talia || Phrase Root: Talia
# NP || Text: a way || Phrase Root: way
# NP || Text: untold emotions || Phrase Root: emotions
# NP || Text: Her character || Phrase Root: character
# NP || Text: the end || Phrase Root: end
# NP || Text: she || Phrase Root: she
# NP || Text: the heroine || Phrase Root: heroine
# NP || Text: Grease || Phrase Root: Grease
# NP || Text: who || Phrase Root: who
# NP || Text: her love || Phrase Root: love
# NP || Text: the end || Phrase Root: end
# NP || Text: Others || Phrase Root: Others
# NP || Text: the movie || Phrase Root: movie
# NP || Text: Burt Young || Phrase Root: Young
# NP || Text: attention-seeking || Phrase Root: seeking
# NP || Text: insecure brother || Phrase Root: brother
# NP || Text: Adrian || Phrase Root: Adrian
# NP || Text: Burgess || Phrase Root: Burgess
# NP || Text: the surly coach || Phrase Root: coach
# NP || Text: a story || Phrase Root: story
# NP || Text: failure || Phrase Root: failure
# NP || Text: the past || Phrase Root: past
# NP || Text: the extreme || Phrase Root: extreme
# NP || Text: Rocky" chants || Phrase Root: chants
# NP || Text: such character || Phrase Root: character
# NP || Text: a college movie || Phrase Root: movie
# NP || Text: unruly youngsters || Phrase Root: youngsters
# NP || Text: i.e. Grease || Phrase Root: Grease
# NP || Text: Carl Weathers' character || Phrase Root: character
# NP || Text: Apollo || Phrase Root: Apollo
# NP || Text: me || Phrase Root: me
# NP || Text: Lady Gaga || Phrase Root: Gaga
# NP || Text: he || Phrase Root: he
# NP || Text: a friendly villain || Phrase Root: villain
# NP || Text: a contrast || Phrase Root: contrast
# NP || Text: other sports movies || Phrase Root: movies
# NP || Text: I || Phrase Root: I
# NP || Text: the old-fashioned ones || Phrase Root: ones
# NP || Text: a figure || Phrase Root: figure
# NP || Text: The story || Phrase Root: story
# NP || Text: times || Phrase Root: times
# NP || Text: a broken tooth || Phrase Root: tooth
# NP || Text: dislocated shoulder || Phrase Root: shoulder
# NP || Text: the middle || Phrase Root: middle
# NP || Text: Two fights || Phrase Root: fights
# NP || Text: a classic sports film || Phrase Root: film
# NP || Text: The direction || Phrase Root: direction
# NP || Text: multiple places || Phrase Root: places
# NP || Text: The background score || Phrase Root: score
# NP || Text: some potential hits || Phrase Root: hits
# NP || Text: an enlivening effect || Phrase Root: effect
# NP || Text: you || Phrase Root: you
# NP || Text: YaY || Phrase Root: YaY
# NP || Text: the end || Phrase Root: end
# NP || Text: the tight budget || Phrase Root: budget
# NP || Text: these slights || Phrase Root: slights
# NP || Text: even films || Phrase Root: films
# NP || Text: shoe-string budget || Phrase Root: budget
# NP || Text: Talia || Phrase Root: Talia
# NP || Text: the talking || Phrase Root: talking
# NP || Text: and Sly more action || Phrase Root: action
# NP || Text: the sequel || Phrase Root: sequel
# NP || Text: I || Phrase Root: I
# NP || Text: I || Phrase Root: I
# NP || Text: it || Phrase Root: it
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: The Loser
# ===================================================================================
# NP || Text: I || Phrase Root: I
# NP || Text: a variety || Phrase Root: variety
# NP || Text: reasons || Phrase Root: reasons
# NP || Text: what || Phrase Root: what
# NP || Text: the scale || Phrase Root: scale
# NP || Text: two "ring" movies || Phrase Root: movies
# NP || Text: The reason || Phrase Root: reason
# NP || Text: Rocky || Phrase Root: Rocky
# NP || Text: the camera || Phrase Root: camera
# NP || Text: the ring business || Phrase Root: business
# NP || Text: I || Phrase Root: I
# NP || Text: it || Phrase Root: it
# NP || Text: the very first movie || Phrase Root: movie
# NP || Text: a way || Phrase Root: way
# NP || Text: you || Phrase Root: you
# NP || Text: the fight || Phrase Root: fight
# NP || Text: you || Phrase Root: you
# NP || Text: the cinematic space || Phrase Root: space
# NP || Text: Scorcese || Phrase Root: Scorcese
# NP || Text: all his many faults || Phrase Root: faults
# NP || Text: an amazing job || Phrase Root: job
# NP || Text: Rocky || Phrase Root: Rocky
# NP || Text: clarity || Phrase Root: clarity
# NP || Text: the dullness || Phrase Root: dullness
# NP || Text: the Rocky character || Phrase Root: character
# NP || Text: the way || Phrase Root: way
# NP || Text: Raging Bull || Phrase Root: Bull
# NP || Text: a new standard || Phrase Root: standard
# NP || Text: the ring || Phrase Root: ring
# NP || Text: " camera-work || Phrase Root: work
# NP || Text: a new vocabulary || Phrase Root: vocabulary
# NP || Text: any two characters || Phrase Root: characters
# NP || Text: Those 360 spins || Phrase Root: spins
# NP || Text: two folks || Phrase Root: folks
# NP || Text: something || Phrase Root: something
# NP || Text: them || Phrase Root: them
# NP || Text: the lowest form || Phrase Root: form
# NP || Text: Anyway, "Redbelt || Phrase Root: Redbelt
# NP || Text: "Wrestler || Phrase Root: Wrestler
# NP || Text: two competent folks || Phrase Root: folks
# NP || Text: I || Phrase Root: I
# NP || Text: I || Phrase Root: I
# NP || Text: Rocky || Phrase Root: Rocky
# NP || Text: I || Phrase Root: I
# NP || Text: the whole series || Phrase Root: series
# NP || Text: What || Phrase Root: What
# NP || Text: we || Phrase Root: we
# NP || Text: the time || Phrase Root: time
# NP || Text: the folding || Phrase Root: folding
# NP || Text: reality || Phrase Root: reality
# NP || Text: the story || Phrase Root: story
# NP || Text: Stallone's story || Phrase Root: story
# NP || Text: his romance || Phrase Root: romance
# NP || Text: a Copolla || Phrase Root: Copolla
# NP || Text: It || Phrase Root: It
# NP || Text: we || Phrase Root: we
# NP || Text: film || Phrase Root: film
# NP || Text: a steadicam || Phrase Root: steadicam
# NP || Text: the steps || Phrase Root: steps
# NP || Text: them || Phrase Root: them
# NP || Text: the ring || Phrase Root: ring
# NP || Text: the time || Phrase Root: time
# NP || Text: it || Phrase Root: it
# NP || Text: it || Phrase Root: it
# NP || Text: what || Phrase Root: what
# NP || Text: we || Phrase Root: we
# NP || Text: the now sharper knowledge || Phrase Root: knowledge
# NP || Text: reality || Phrase Root: reality
# NP || Text: the fiction || Phrase Root: fiction
# NP || Text: And the story || Phrase Root: story
# NP || Text: course || Phrase Root: course
# NP || Text: me || Phrase Root: me
# NP || Text: everything || Phrase Root: everything
# NP || Text: attention || Phrase Root: attention
# NP || Text: the dialog || Phrase Root: dialog
# NP || Text: every word || Phrase Root: word
# NP || Text: Stallone || Phrase Root: Stallone
# NP || Text: his own speeches || Phrase Root: speeches
# NP || Text: the well delivered but trite speeches || Phrase Root: speeches
# NP || Text: others || Phrase Root: others
# NP || Text: an adventure || Phrase Root: adventure
# NP || Text: me || Phrase Root: me
# NP || Text: the Rocky and Rambo stuff || Phrase Root: stuff
# NP || Text: I || Phrase Root: I
# NP || Text: Stallone || Phrase Root: Stallone
# NP || Text: Ted's Evaluation || Phrase Root: Evaluation
# NP || Text: some interesting elements || Phrase Root: elements
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: A triumph of self-pitying losers
# ===================================================================================
# NP || Text: I || Phrase Root: I
# NP || Text: the story || Phrase Root: story
# NP || Text: the creation || Phrase Root: creation
# NP || Text: Rocky || Phrase Root: Rocky
# NP || Text: Stallone || Phrase Root: Stallone
# NP || Text: a very hard time || Phrase Root: time
# ...
# NP || Text: I || Phrase Root: I
# NP || Text: his presence || Phrase Root: presence
# NP || Text: Mr. T. || Phrase Root: T.
# NP || Text: a marketing choice || Phrase Root: choice
# NP || Text: it's purpose || Phrase Root: purpose
# NP || Text: he || Phrase Root: he
# NP || Text: the top || Phrase Root: top
# NP || Text: his scenes || Phrase Root: scenes
# NP || Text: The dialogs || Phrase Root: dialogs
# NP || Text: it || Phrase Root: it
# NP || Text: a Rocky movie || Phrase Root: movie
# NP || Text: You || Phrase Root: You
# NP || Text: our hero || Phrase Root: hero
# NP || Text: the worst situations || Phrase Root: situations
# NP || Text: the end || Phrase Root: end
# NP || Text: Rocky fans || Phrase Root: fans
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky 3 Review Title: Almost loses "The Eye of the Tiger" half-way through
# ===================================================================================
# NP || Text: Rocky Balboa || Phrase Root: Balboa
# NP || Text: Sylvester Stallone || Phrase Root: Stallone
# NP || Text: who || Phrase Root: who
# NP || Text: the movie || Phrase Root: movie
# NP || Text: the Professional Boxing World Heavyweight Champion || Phrase Root: Champion
# NP || Text: the life || Phrase Root: life
# NP || Text: he || Phrase Root: he
# NP || Text: He || Phrase Root: He
# NP || Text: a huge house || Phrase Root: house
# NP || Text: his family || Phrase Root: family
# NP || Text: the cover || Phrase Root: cover
# NP || Text: various magazines || Phrase Root: magazines
# NP || Text: numerous endorsement deals || Phrase Root: deals
# NP || Text: him || Phrase Root: him
# NP || Text: he || Phrase Root: he
# NP || Text: the ring || Phrase Root: ring
# NP || Text: the point || Phrase Root: point
# NP || Text: his manager || Phrase Root: manager
# NP || Text: Mickey || Phrase Root: Mickey
# NP || Text: Burgess Meredith || Phrase Root: Meredith
# NP || Text: him || Phrase Root: him
# NP || Text: bouts || Phrase Root: bouts
# NP || Text: inferior fighters || Phrase Root: fighters
# NP || Text: the ring || Phrase Root: ring
# NP || Text: the cocky professional wrestling star || Phrase Root: star
# NP || Text: (Hulk Hogan || Phrase Root: Hogan
# NP || Text: his acting debut || Phrase Root: debut
# NP || Text: He || Phrase Root: He
# NP || Text: his edge || Phrase Root: edge
# NP || Text: Mickey || Phrase Root: Mickey
# NP || Text: it || Phrase Root: it
# NP || Text: the champ || Phrase Root: champ
# NP || Text: it || Phrase Root: it
# NP || Text: He || Phrase Root: He
# NP || Text: Mickey's" orders || Phrase Root: orders
# NP || Text: the challenge || Phrase Root: challenge
# NP || Text: "Clubber Lang || Phrase Root: Lang
# NP || Text: Mr. T || Phrase Root: T
# NP || Text: his most famous roles || Phrase Root: roles
# NP || Text: a tough, bad attitude boxer || Phrase Root: boxer
# NP || Text: who || Phrase Root: who
# NP || Text: the Number One Contendership || Phrase Root: Contendership
# NP || Text: himself || Phrase Root: himself
# NP || Text: no trainer || Phrase Root: trainer
# NP || Text: him || Phrase Root: him
# NP || Text: Mickey || Phrase Root: Mickey
# NP || Text: Balboa || Phrase Root: Balboa
# NP || Text: Lang's challenge || Phrase Root: challenge
# NP || Text: the mohawked fighter || Phrase Root: fighter
# NP || Text: the champ's wife || Phrase Root: wife
# NP || Text: Talia Shire || Phrase Root: Shire
# NP || Text: a public appearance || Phrase Root: appearance
# NP || Text: He || Phrase Root: He
# NP || Text: the challenge || Phrase Root: challenge
# NP || Text: Mickey || Phrase Root: Mickey
# NP || Text: Balboa || Phrase Root: Balboa
# NP || Text: the title || Phrase Root: title
# NP || Text: Lang || Phrase Root: Lang
# NP || Text: things || Phrase Root: things
# NP || Text: Mickey || Phrase Root: Mickey
# NP || Text: a confrontation || Phrase Root: confrontation
# NP || Text: "Balboa || Phrase Root: Balboa
# NP || Text: "Lang || Phrase Root: Lang
# NP || Text: the dressing room || Phrase Root: room
# NP || Text: Lang || Phrase Root: Lang
# NP || Text: the champion || Phrase Root: champion
# NP || Text: the title || Phrase Root: title
# NP || Text: Balboa || Phrase Root: Balboa
# NP || Text: what || Phrase Root: what
# NP || Text: he || Phrase Root: he
# NP || Text: he || Phrase Root: he
# NP || Text: help || Phrase Root: help
# NP || Text: an old rival || Phrase Root: rival
# NP || Text: Carl Weathers || Phrase Root: Weathers
# NP || Text: A rival || Phrase Root: rival
# NP || Text: who || Phrase Root: who
# NP || Text: the "Eye || Phrase Root: Eye
# NP || Text: the Tiger || Phrase Root: Tiger
# NP || Text: he || Phrase Root: he
# NP || Text: "The Italian Stallion || Phrase Root: Stallion
# NP || Text: himself || Phrase Root: himself
# NP || Text: the title || Phrase Root: title
# NP || Text: one slow moving movie || Phrase Root: movie
# NP || Text: especially about half-way || Phrase Root: way
# NP || Text: the film || Phrase Root: film
# NP || Text: I || Phrase Root: I
# NP || Text: myself || Phrase Root: myself
# NP || Text: websites || Phrase Root: websites
# NP || Text: that time || Phrase Root: time
# NP || Text: the film || Phrase Root: film
# NP || Text: Demand || Phrase Root: Demand
# NP || Text: It || Phrase Root: It
# NP || Text: the rematch || Phrase Root: rematch
# NP || Text: the two boxing rivals || Phrase Root: rivals
# NP || Text: the time || Phrase Root: time
# NP || Text: Apollo Creed || Phrase Root: Creed
# NP || Text: The acting || Phrase Root: acting
# NP || Text: You || Phrase Root: You
# NP || Text: Balboa || Phrase Root: Balboa
# NP || Text: he || Phrase Root: he
# NP || Text: his edge || Phrase Root: edge
# NP || Text: Stallone's performance || Phrase Root: performance
# NP || Text: the scene || Phrase Root: scene
# NP || Text: the death || Phrase Root: death
# NP || Text: Mickey || Phrase Root: Mickey
# NP || Text: him || Phrase Root: him
# NP || Text: Certain cast members || Phrase Root: members
# NP || Text: characters || Phrase Root: characters
# NP || Text: who || Phrase Root: who
# NP || Text: the previous two movies || Phrase Root: movies
# NP || Text: I || Phrase Root: I
# NP || Text: they || Phrase Root: they
# NP || Text: they || Phrase Root: they
# NP || Text: the storyline || Phrase Root: storyline
# NP || Text: they || Phrase Root: they
# NP || Text: part || Phrase Root: part
# NP || Text: the series || Phrase Root: series
# NP || Text: the first movie || Phrase Root: movie
# NP || Text: the franchise || Phrase Root: franchise
# NP || Text: I || Phrase Root: I
# NP || Text: the chemistry || Phrase Root: chemistry
# NP || Text: Stallone || Phrase Root: Stallone
# NP || Text: Weathers || Phrase Root: Weathers
# NP || Text: this film || Phrase Root: film
# NP || Text: previous films || Phrase Root: films
# NP || Text: they || Phrase Root: they
# NP || Text: rivals || Phrase Root: rivals
# NP || Text: they || Phrase Root: they
# NP || Text: the same side || Phrase Root: side
# NP || Text: They || Phrase Root: They
# NP || Text: two professionals || Phrase Root: professionals
# NP || Text: the toughest sports || Phrase Root: sports
# NP || Text: the planet || Phrase Root: planet
# NP || Text: a teacher || Phrase Root: teacher
# NP || Text: a rival || Phrase Root: rival
# NP || Text: who || Phrase Root: who
# NP || Text: the title || Phrase Root: title
# NP || Text: his now-student || Phrase Root: student
# NP || Text: Weathers || Phrase Root: Weathers
# NP || Text: this role || Phrase Root: role
# NP || Text: the audience || Phrase Root: audience
# NP || Text: he || Phrase Root: he
# NP || Text: the first movie || Phrase Root: movie
# NP || Text: Another breakout performance || Phrase Root: performance
# NP || Text: Mr. T. Surprisingly || Phrase Root: Surprisingly
# NP || Text: Balboa || Phrase Root: Balboa
# NP || Text: his edge || Phrase Root: edge
# NP || Text: Lang || Phrase Root: Lang
# NP || Text: The film || Phrase Root: film
# NP || Text: "Balboa" training || Phrase Root: training
# NP || Text: the rematch || Phrase Root: rematch
# NP || Text: "Lang || Phrase Root: Lang
# NP || Text: the life || Phrase Root: life
# NP || Text: the defending champion || Phrase Root: champion
# NP || Text: You || Phrase Root: You
# NP || Text: he || Phrase Root: he
# NP || Text: the movie || Phrase Root: movie
# NP || Text: he || Phrase Root: he
# NP || Text: the story || Phrase Root: story
# NP || Text: the rematch || Phrase Root: rematch
# NP || Text: I || Phrase Root: I
# NP || Text: some references || Phrase Root: references
# NP || Text: Lang || Phrase Root: Lang
# NP || Text: "Balboa || Phrase Root: Balboa
# NP || Text: training || Phrase Root: training
# NP || Text: the role || Phrase Root: role
# NP || Text: Mr. T || Phrase Root: T
# NP || Text: his tough guy image || Phrase Root: image
# NP || Text: He || Phrase Root: He
# NP || Text: the bad guy || Phrase Root: guy
# NP || Text: you || Phrase Root: you
# NP || Text: This film || Phrase Root: film
# NP || Text: You || Phrase Root: You
# NP || Text: who || Phrase Root: who
# NP || Text: the end || Phrase Root: end
# NP || Text: I || Phrase Root: I
# NP || Text: some plot twists || Phrase Root: twists
# NP || Text: the end || Phrase Root: end
# NP || Text: Another problem || Phrase Root: problem
# NP || Text: this film || Phrase Root: film
# NP || Text: the soundtrack || Phrase Root: soundtrack
# NP || Text: I || Phrase Root: I
# NP || Text: two songs || Phrase Root: songs
# NP || Text: the film || Phrase Root: film
# NP || Text: the "Rocky Theme" piece || Phrase Root: piece
# NP || Text: you || Phrase Root: you
# NP || Text: it || Phrase Root: it
# NP || Text: "Eye || Phrase Root: Eye
# NP || Text: the Tiger || Phrase Root: Tiger
# NP || Text: the one-hit-wonder || Phrase Root: wonder
# NP || Text: this song || Phrase Root: song
# NP || Text: Survivor || Phrase Root: Survivor
# NP || Text: Another problem || Phrase Root: problem
# NP || Text: this film || Phrase Root: film
# NP || Text: times || Phrase Root: times
# NP || Text: it || Phrase Root: it
# NP || Text: Stallone's speaking || Phrase Root: speaking
# NP || Text: times || Phrase Root: times
# NP || Text: I || Phrase Root: I
# NP || Text: what || Phrase Root: what
# NP || Text: others || Phrase Root: others
# NP || Text: the scene || Phrase Root: scene
# NP || Text: response || Phrase Root: response
# NP || Text: what || Phrase Root: what
# NP || Text: you || Phrase Root: you
# NP || Text: the other movies || Phrase Root: movies
# NP || Text: I || Phrase Root: I
# NP || Text: this film || Phrase Root: film
# NP || Text: VHS/DVD || Phrase Root: DVD
# NP || Text: the series || Phrase Root: series
# NP || Text: I || Phrase Root: I
# NP || Text: a pretty good third choice || Phrase Root: choice
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky 3 Review Title: Not pitiable... though not far off from it, either
# ===================================================================================
# NP || Text: Our protagonist(Sly || Phrase Root: protagonist(Sly
# NP || Text: spite || Phrase Root: spite
# NP || Text: greater fame || Phrase Root: fame
# NP || Text: wealth || Phrase Root: wealth
# NP || Text: the up-and-comer, Clubber Lang(Mr || Phrase Root: Lang(Mr
# NP || Text: T || Phrase Root: T
# NP || Text: his tough image || Phrase Root: image
# NP || Text: a fear || Phrase Root: fear
# NP || Text: He || Phrase Root: He
# NP || Text: fortunate assault laws || Phrase Root: laws
# NP || Text: who || Phrase Root: who
# NP || Text: the ring || Phrase Root: ring
# NP || Text: he || Phrase Root: he
# NP || Text: his underdog status || Phrase Root: status
# NP || Text: intense Meredith) health || Phrase Root: health
# NP || Text: he || Phrase Root: he
# NP || Text: the great big cold continent || Phrase Root: continent
# NP || Text: the sky || Phrase Root: sky
# NP || Text: Adrian(Shire || Phrase Root: Adrian(Shire
# NP || Text: They || Phrase Root: They
# NP || Text: what || Phrase Root: what
# NP || Text: her || Phrase Root: her
# NP || Text: It || Phrase Root: It
# NP || Text: the love || Phrase Root: love
# NP || Text: the elements || Phrase Root: elements
# NP || Text: us || Phrase Root: us
# NP || Text: who || Phrase Root: who
# NP || Text: the macho crap || Phrase Root: crap
# NP || Text: What || Phrase Root: What
# NP || Text: I || Phrase Root: I
# NP || Text: sale || Phrase Root: sale
# NP || Text: they || Phrase Root: they
# NP || Text: him || Phrase Root: him
# NP || Text: what || Phrase Root: what
# NP || Text: they || Phrase Root: they
# NP || Text: her || Phrase Root: her
# NP || Text: Paulie's(Young || Phrase Root: Paulie's(Young
# NP || Text: still gritty) racism || Phrase Root: racism
# NP || Text: the forefront || Phrase Root: forefront
# NP || Text: Creed(Weathers || Phrase Root: Creed(Weathers
# NP || Text: less showy || Phrase Root: showy
# NP || Text: Duke(Burton || Phrase Root: Duke(Burton
# NP || Text: unlikely allies || Phrase Root: allies
# NP || Text: It || Phrase Root: It
# NP || Text: a matter || Phrase Root: matter
# NP || Text: time || Phrase Root: time
# NP || Text: they || Phrase Root: they
# NP || Text: at least one actual fighter || Phrase Root: fighter
# NP || Text: an actor || Phrase Root: actor
# NP || Text: former football player || Phrase Root: player
# NP || Text: we || Phrase Root: we
# NP || Text: Wrong sport || Phrase Root: sport
# NP || Text: course || Phrase Root: course
# NP || Text: it || Phrase Root: it
# NP || Text: the right direction || Phrase Root: direction
# NP || Text: the fights || Phrase Root: fights
# NP || Text: wrestling || Phrase Root: wrestling
# NP || Text: the time || Phrase Root: time
# NP || Text: I || Phrase Root: I
# NP || Text: this point || Phrase Root: point
# NP || Text: the franchise || Phrase Root: franchise
# NP || Text: my mind || Phrase Root: mind
# NP || Text: what || Phrase Root: what
# NP || Text: I || Phrase Root: I
# NP || Text: the second installment || Phrase Root: installment
# NP || Text: more than one movie || Phrase Root: movie
# NP || Text: I || Phrase Root: I
# NP || Text: me || Phrase Root: me
# NP || Text: Part || Phrase Root: Part
# NP || Text: the point || Phrase Root: point
# NP || Text: he || Phrase Root: he
# NP || Text: it || Phrase Root: it
# NP || Text: his last chance || Phrase Root: chance
# NP || Text: The problem || Phrase Root: problem
# NP || Text: a series || Phrase Root: series
# NP || Text: this genre || Phrase Root: genre
# NP || Text: we || Phrase Root: we
# NP || Text: it || Phrase Root: it
# NP || Text: a climactic showdown || Phrase Root: showdown
# NP || Text: Action flicks || Phrase Root: flicks
# NP || Text: thrillers || Phrase Root: thrillers
# NP || Text: dramas || Phrase Root: dramas
# NP || Text: it || Phrase Root: it
# NP || Text: the consequences || Phrase Root: consequences
# NP || Text: it || Phrase Root: it
# NP || Text: emotional, not only physical, stakes || Phrase Root: stakes
# NP || Text: We || Phrase Root: We
# NP || Text: it || Phrase Root: it
# NP || Text: the signs || Phrase Root: signs
# NP || Text: we || Phrase Root: we
# NP || Text: it || Phrase Root: it
# NP || Text: You || Phrase Root: You
# NP || Text: top || Phrase Root: top
# NP || Text: what || Phrase Root: what
# NP || Text: it || Phrase Root: it
# NP || Text: the rules || Phrase Root: rules
# NP || Text: that territory || Phrase Root: territory
# NP || Text: credits || Phrase Root: credits
# NP || Text: a half || Phrase Root: half
# NP || Text: a lot || Phrase Root: lot
# NP || Text: brutal boxing || Phrase Root: boxing
# NP || Text: some strong language || Phrase Root: language
# NP || Text: I || Phrase Root: I
# NP || Text: it || Phrase Root: it
# NP || Text: completionists || Phrase Root: completionists
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# Wall time: 2min 37s

# %% [markdown]
# #### 5.3 - Pattern Chunking
# The Pattern modules parsetree also provides a method for sentence chunking as well.  The Pattern chunking also identifies noun phrases while also showing part of speech tags.  Additionally, certain proper names such as "Sylvester Stallone" are recongnized as the name of a person.  Even with a 0.75 second sleep for each journey through the for loop (too control the rate of messages sent through the jupyter server), the pattern chunker only takes approximately 2.5 minutes to complete its work on the same server as the Spacy chunker.

# %%
# %%time

for r, m, t in zip(dfReviewDetails.Review, dfReviewDetails.Movie, dfReviewDetails.ReviewTitle):
    print("===================================================================================")
    print("===  Movie:", m, "Review Title:", t)
    print("===================================================================================")
    pt = parsetree(r)
    for p in pt:
        for chunk in p.chunks:
            if chunk.type == 'NP':
                print(chunk.type, [(w.string, w.type) for w in chunk.words])
    print("===================================================================================")
    print("=================================== End Review ====================================")
    print("===================================================================================")
    sleep(0.75)
# Out:
# ===================================================================================
# ===  Movie: Rocky Review Title: Dumbest, Most Cornball Film Ever Made
# ===================================================================================
# NP [('I', 'PRP')]
# NP [('my', 'PRP$'), ('initial', 'JJ'), ('outrage', 'NN')]
# NP [('this', 'DT'), ('piece', 'NN')]
# NP [('sentimental', 'JJ'), ('slop', 'NN')]
# NP [('they', 'PRP')]
# NP [('this', 'DT'), ('movie', 'NN')]
# NP [('so', 'RB'), ('many', 'JJ'), ('cliches', 'NNS')]
# NP [('stupidities', 'NNS')]
# NP [('it', 'PRP')]
# NP [('all', 'DT'), ('time', 'NN')]
# NP [('ignorant', 'JJ'), ('Hollywood', 'NNP')]
# NP [('public', 'NN')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: Rubbish
# ===================================================================================
# NP [('The', 'DT'), ('fight', 'NN'), ('scenes', 'NNS')]
# NP [('the', 'DT'), ('acting', 'NN')]
# NP [('Rubbish', 'NN')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: overrated piece of cheese
# ===================================================================================
# NP [('grubby', 'JJ'), ('late-night', 'JJ'), ('fare', 'NN')]
# NP [('way', 'NN'), ('too', 'RB'), ('much', 'JJ'), ('success', 'NN')]
# NP [('a', 'DT'), ('primitive', 'JJ'), ('story', 'NN')]
# NP [('A', 'DT'), ('silly', 'JJ'), ('promotional', 'JJ'), ('song', 'NN')]
# NP [('laughable', 'JJ'), ('script', 'NN')]
# NP [('performances', 'NNS')]
# NP [('I', 'PRP')]
# NP [('no', 'DT'), ('clue', 'NN')]
# NP [('this', 'DT'), ('picture', 'NN')]
# NP [('its', 'PRP$'), ('heart', 'NN')]
# NP [('its', 'PRP$'), ('sleeve', 'NN')]
# NP [('the', 'DT'), ('critcal', 'JJ'), ('appreciation', 'NN')]
# NP [('it', 'PRP')]
# NP [('concept', 'NN'), ('film', 'NN')]
# NP [('it', 'PRP')]
# NP [('herald', 'PDT'), ('the', 'DT'), ('wave', 'NN')]
# NP [('brain', 'NN'), ('feel-good', 'JJ'), ('fare', 'NN')]
# NP [('the', 'DT'), ('eighties', 'NNS')]
# NP [('the', 'DT'), ('present', 'NN')]
# NP [('It', 'PRP')]
# NP [('racist', 'NN')]
# NP [('a', 'DT'), ('boxing', 'NN'), ('champ', 'NN')]
# NP [('Apollo', 'NNP'), ('Creed', 'NNP')]
# NP [('the', 'DT'), ('bout', 'NN')]
# NP [('the', 'DT'), ('audience', 'NN')]
# NP [('the', 'DT'), ('ring', 'NN')]
# NP [('his', 'PRP$'), ('eyelid', 'NN'), ('cut', 'NN')]
# NP [('a', 'DT'), ('razor', 'NN'), ('blade', 'NN')]
# NP [('he', 'PRP')]
# NP [('fighting', 'NN')]
# NP [('I', 'PRP')]
# NP [('the', 'DT'), ('sequels', 'NNS')]
# NP [('Aki', 'NNP'), ('Kaurismaki', 'NNP')]
# NP [('_', 'NNP'), ('Rocky', 'NNP'), ('VI', 'NNP'), ('_', 'NNP')]
# NP [('even', 'RB'), ('more', 'JJR'), ('laugh', 'NN')]
# NP [('provoking', 'NN')]
# NP [('this', 'DT'), ('film', 'NN')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: Eh....it was alright.
# ===================================================================================
# NP [('I', 'PRP')]
# NP [('this', 'DT'), ('movie', 'NN')]
# NP [('Dimwitted', 'JJ'), ('athletes', 'NNS')]
# NP [('interest', 'NN'), ('me', 'PRP')]
# NP [('I', 'PRP')]
# NP [('it', 'PRP')]
# NP [('no', 'DT'), ('accounting', 'NN')]
# NP [('the', 'DT'), ('public', 'NN')]
# NP [('taste', 'NN')]
# NP [('I', 'PRP')]
# NP [('sports', 'NNS'), ('movies', 'NNS')]
# NP [('I', 'PRP')]
# NP [('a', 'DT'), ('pure', 'JJ'), ('sports', 'NNS'), ('movie', 'NN')]
# NP [('I', 'PRP')]
# NP [('it', 'PRP')]
# NP [('The', 'DT'), ('music', 'NN')]
# NP [('me', 'PRP')]
# NP [('I', 'PRP')]
# NP [('they', 'PRP')]
# NP [('annoying', 'JJ'), ('music', 'NN')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: I can't believe the script was made into a movie...
# ===================================================================================
# NP [('I', 'PRP')]
# NP [('Rocky', 'NNP')]
# NP [('a', 'DT'), ('beautiful', 'JJ'), ('movie', 'NN')]
# NP [('I', 'PRP')]
# NP [('I', 'PRP')]
# NP [('The', 'DT'), ('movie', 'NN')]
# NP [('the', 'DT'), ('same', 'JJ'), ('annoyingly', 'RB'), ('slow', 'JJ'), ('pace', 'NN')]
# NP [('the', 'DT'), ('clichéd', 'NN'), ('characters', 'NNS')]
# NP [('Stalone', 'NNP')]
# NP [('the', 'DT'), ('plot', 'NN')]
# NP [('I', 'PRP')]
# NP [('its', 'PRP$')]
# NP [('a', 'DT'), ('plot', 'NN')]
# NP [('you', 'PRP')]
# NP [('the', 'DT'), ('end', 'NN')]
# NP [('your', 'PRP$'), ('eyes', 'NNS')]
# NP [('you', 'PRP')]
# NP [('grass', 'NN')]
# NP [('this', 'DT'), ('movie', 'NN')]
# NP [('a', 'DT'), ('little', 'JJ'), ('fast', 'NN')]
# NP [('you', 'PRP')]
# NP [('a', 'DT'), ('story', 'NN')]
# NP [('intellect', 'NN'), ('you', 'PRP')]
# NP [('the', 'DT'), ('plot', 'NN'), ('gripping', 'NN')]
# NP [('I', 'PRP')]
# NP [('it', 'PRP'), ('and', 'CC'), ('I', 'PRP')]
# NP [('my', 'PRP$'), ('time', 'NN')]
# NP [('It', 'PRP')]
# NP [('I', 'PRP')]
# NP [('this', 'DT'), ('mind', 'NN')]
# NP [('numbing', 'JJ'), ('movie', 'NN')]
# NP [('anyone', 'NN')]
# NP [('I', 'PRP')]
# NP [('them', 'PRP')]
# NP [('my', 'PRP$'), ('friends', 'NNS')]
# NP [('me', 'PRP')]
# NP [('it', 'PRP')]
# NP [('a', 'DT'), ('practical', 'JJ'), ('joke', 'NN')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: The most overrated movie of all time
# ===================================================================================
# NP [('I', 'PRP')]
# NP [('this', 'DT'), ('movie', 'NN')]
# NP [('it', 'PRP')]
# NP [('I', 'PRP')]
# NP [('Sylvester', 'NNP-PERS'), ('Stallone', 'NNP-PERS')]
# NP [('no', 'DT'), ('expectations', 'NNS')]
# NP [('preconceptions', 'NNS')]
# NP [('it', 'PRP')]
# NP [('a', 'DT'), ('good', 'JJ'), ('depiction', 'NN')]
# NP [('boxing', 'NN')]
# NP [('I', 'PRP')]
# NP [('it', 'PRP')]
# NP [('I', 'PRP')]
# NP [('the', 'DT'), ('theater', 'NN')]
# NP [('I', 'PRP')]
# NP [('it', 'PRP')]
# NP [('The', 'DT'), ('film', 'NN')]
# NP [('sappiest', 'NN'), ('pieces', 'NNS')]
# NP [('melodramatic', 'JJ'), ('tripe', 'NN'), ('I', 'PRP')]
# NP [('Every', 'DT'), ('character', 'NN')]
# NP [('a', 'DT'), ('stereotype', 'NN')]
# NP [('every', 'DT'), ('turn', 'NN')]
# NP [('its', 'PRP$'), ('derivative', 'JJ'), (',', ','), ('amateurish', 'JJ'), ('plot', 'NN')]
# NP [('50', 'CD'), ('miles', 'NNS')]
# NP [('the', 'DT'), ('boxing', 'NN')]
# NP [('a', 'DT'), ('Popeye', 'NNP'), ('cartoon', 'NN')]
# NP [('more', 'RBR'), ('realistic', 'JJ'), ('action', 'NN')]
# NP [('It', 'PRP')]
# NP [('the', 'DT'), ('most', 'RBS'), ('ludicrous', 'JJ'), ('exhibitions', 'NNS')]
# NP [('professional', 'JJ'), ('wrestling', 'NN'), ('matches', 'NNS')]
# NP [('two', 'CD'), ('minutes', 'NNS')]
# NP [('the', 'DT'), ('kind', 'NN')]
# NP [('pummeling', 'NN')]
# NP [('the', 'DT'), ('title', 'NN'), ('fight', 'NN')]
# NP [('brain', 'NN')]
# NP [('My', 'PRP$'), ('contempt', 'NN')]
# NP [('this', 'DT'), ('trash', 'NN')]
# NP [('even', 'RB'), ('greater', 'JJR'), ('depths', 'NNS')]
# NP [('I', 'PRP')]
# NP [('it', 'PRP')]
# NP [('three', 'CD'), ('outstanding', 'JJ'), ('movies', 'NNS')]
# NP [('Network', 'NNP')]
# NP [('Taxi', 'NN'), ('Driver', 'NNP')]
# NP [('All', 'PDT'), ('the', 'DT'), ('President', 'NNP')]
# NP [('Men', 'NN')]
# NP [('the', 'DT'), ('best', 'JJS'), ('picture', 'NN'), ('Oscar', 'NNP')]
# NP [('I', 'PRP')]
# NP [('Bound', 'NNP')]
# NP [('Glory', 'NN')]
# NP [('I', 'PRP')]
# NP [('no', 'DT'), ('doubt', 'NN'), ('it', 'PRP')]
# NP [('a', 'DT'), ('far', 'RB'), ('better', 'JJR'), ('movie', 'NN')]
# NP [('this', 'DT'), ('drivel', 'NN')]
# NP [('I', 'PRP')]
# NP [('a', 'DT'), ('portion', 'NN')]
# NP [('the', 'DT'), ('public', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('I', 'PRP')]
# NP [('no', 'DT'), ('excuse', 'NN')]
# NP [('the', 'DT'), ('voting', 'NN')]
# NP [('the', 'DT'), ('Academy', 'NNP'), ('members', 'NNS')]
# NP [('Shame', 'NNP')]
# NP [('them', 'PRP')]
# NP [('this', 'DT'), ('sorry', 'JJ'), ('excuse', 'NN')]
# NP [('a', 'DT'), ('movie', 'NN')]
# NP [('such', 'JJ'), ('worthy', 'JJ'), ('contenders', 'NNS')]
# NP [('It', 'PRP')]
# NP [('as', 'RB'), ('much', 'JJ'), ('sense', 'NN')]
# NP [('a', 'DT'), ('punch-drunk', 'NN'), ('bar-fighting', 'NN'), ('buffoon', 'NN'), ('landing', 'NN')]
# NP [('a', 'DT'), ('title', 'NN'), ('fight', 'NN')]
# NP [('Muhammad', 'NNP-PERS'), ('Ali', 'NNP')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: Hate me if you want but I didn't like this film
# ===================================================================================
# NP [('I', 'PRP')]
# NP [('it', 'PRP')]
# NP [('I', 'PRP')]
# NP [('this', 'DT'), ('film', 'NN')]
# NP [('I', 'PRP')]
# NP [('me', 'PRP'), ('hate', 'NN')]
# NP [('it', 'PRP')]
# NP [('the', 'DT'), ('truth', 'NN')]
# NP [('I', 'PRP')]
# NP [('any', 'DT'), ('interest', 'NN')]
# NP [('boxing', 'NN')]
# NP [('the', 'DT'), ('film', 'NN')]
# NP [('content', 'NN'), ('or', 'CC'), ('Rocky', 'NNP')]
# NP [('struggle', 'NN')]
# NP [('me', 'PRP')]
# NP [('it', 'PRP')]
# NP [('I', 'PRP')]
# NP [('Stallone', 'NNP')]
# NP [('portrayal', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('his', 'PRP$')]
# NP [('his', 'PRP$'), ('shouting', 'NN')]
# NP [('I', 'PRP')]
# NP [('anything', 'NN')]
# NP [('that', 'WDT'), ('he', 'PRP')]
# NP [('me', 'PRP')]
# NP [('the', 'DT'), ('character', 'NN')]
# NP [('all', 'DT'), ('credit', 'NN')]
# NP [('the', 'DT'), ('set-designers', 'NNS')]
# NP [('Rocky', 'NNP')]
# NP [('apartment', 'NN')]
# NP [('a', 'DT'), ('horrible', 'JJ'), ('place', 'NN')]
# NP [('wallpaper', 'NN')]
# NP [('thank', 'NN'), ('God', 'NNP')]
# NP [('Burgess', 'NNP'), ('Meredith', 'NNP')]
# NP [('it', 'PRP')]
# NP [('my', 'PRP$'), ('full', 'JJ'), ('review', 'NN')]
# NP [('http://goo.gl/mM9IxQ', 'NNP')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: Vastly overrated
# ===================================================================================
# NP [('the', 'DT'), ('Best', 'NNP'), ('Picture', 'NNP'), ('Oscar', 'NNP')]
# NP [('Story', 'NNP')]
# NP [('spells', 'NNS')]
# NP [('The', 'DT'), ('opening', 'JJ'), ('setup', 'NN')]
# NP [('it', 'PRP')]
# NP [('a', 'DT'), ('picture', 'NN')]
# NP [('a', 'DT'), ('man', 'NN')]
# NP [('a', 'DT'), ('dead-end', 'JJ'), ('situation', 'NN')]
# NP [('you', 'PRP')]
# NP [('the', 'DT'), ('movie', 'NN')]
# NP [('he', 'PRP')]
# NP [('himself', 'PRP')]
# NP [('that', 'DT'), ('situation', 'NN')]
# NP [('it', 'PRP')]
# NP [('it', 'PRP')]
# NP [('a', 'DT'), ('lottery', 'NN')]
# NP [('hard', 'JJ'), ('work', 'NN')]
# NP [('The', 'DT'), ('only', 'JJ'), ('thing', 'NN')]
# NP [('it', 'PRP')]
# NP [('the', 'DT'), ('fight', 'NN'), ('scene', 'NN')]
# NP [('the', 'DT'), ('end', 'NN')]
# NP [('The', 'DT'), ('Rocky-Adrian', 'JJ'), ('relationship', 'NN')]
# NP [('injury', 'NN')]
# NP [('Sylvester', 'NNP-PERS'), ('Stallone', 'NNP-PERS')]
# NP [('a', 'DT'), ('Best', 'NNP'), ('Actor', 'NNP'), ('Oscar', 'NNP'), ('nomination', 'NN')]
# NP [('his', 'PRP$'), ('series', 'NN')]
# NP [('monosyllabic', 'JJ'), ('grunts', 'NNS')]
# NP [('dialogue', 'NN')]
# NP [('total', 'NN'), ('Rocky', 'NNP')]
# NP [('three', 'CD'), ('Academy', 'NNP'), ('awards', 'NNS')]
# NP [('seven', 'CD'), ('other', 'JJ'), ('nominations', 'NNS')]
# NP [('the', 'DT'), ('nomination', 'NN')]
# NP [('Best', 'NNP'), ('Original', 'NNP'), ('Song', 'NNP')]
# NP [('the', 'DT'), ('most', 'JJS'), ('over-rated', 'JJ'), ('and', 'CC'), ('over-awarded', 'JJ'), ('films', 'NNS')]
# NP [('history', 'NN')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: A screaming movie with some boxing undertones
# ===================================================================================
# NP [('It', 'PRP')]
# NP [('a', 'DT'), ('long', 'JJ'), ('time', 'NN')]
# NP [('I', 'PRP')]
# NP [('it', 'PRP')]
# NP [('I', 'PRP')]
# NP [('it', 'PRP')]
# NP [('a', 'DT'), ('movie', 'NN')]
# NP [('boxing', 'NN')]
# NP [('an', 'DT'), ('underdog', 'NN')]
# NP [('a', 'DT'), ('chance', 'NN')]
# NP [('it', 'PRP')]
# NP [('I', 'PRP')]
# NP [('it', 'PRP')]
# NP [('I', 'PRP')]
# NP [('it', 'PRP')]
# NP [('fact', 'NN'), ('a', 'DT'), ('movie', 'NN')]
# NP [('the', 'DT'), ('dangers', 'NNS')]
# NP [('brain', 'NN'), ('damage', 'NN')]
# NP [('Every', 'DT'), ('single', 'JJ'), ('person', 'NN')]
# NP [('this', 'DT'), ('movie', 'NN')]
# NP [('brain', 'NN')]
# NP [('the', 'DT'), ('boxers', 'NNS')]
# NP [('trainers', 'NNS')]
# NP [('the', 'DT'), ('ice', 'NN'), ('rink', 'NN'), ('janitor', 'NN')]
# NP [('meat', 'NN')]
# NP [('half-wit', 'NN')]
# NP [('a', 'DT'), ('couple', 'NN')]
# NP [('different', 'JJ'), ('ways', 'NNS')]
# NP [('most', 'RBS'), ('irritating', 'JJ'), ('one', 'NN')]
# NP [('the', 'DT'), ('way', 'NN'), ('people', 'NNS')]
# NP [('people', 'NNS')]
# NP [('Everything', 'NN')]
# NP [('match', 'NN')]
# NP [('It', 'PRP')]
# NP [('Many', 'JJ'), ('parts', 'NNS')]
# NP [('the', 'DT'), ('movie', 'NN')]
# NP [('The', 'DT'), ('premise', 'NN')]
# NP [('itself', 'PRP')]
# NP [('The', 'DT'), ('boxing', 'NN'), ('parts', 'NNS')]
# NP [('it', 'PRP')]
# NP [('us', 'PRP')]
# NP [('it', 'PRP')]
# NP [('All', 'DT'), ('other', 'JJ'), ('things', 'NNS')]
# NP [('first', 'JJ'), ('hour', 'NN')]
# NP [('the', 'DT'), ('movie', 'NN')]
# NP [('the', 'DT'), ('rest', 'NN')]
# NP [('you', 'PRP')]
# NP [('it', 'PRP')]
# NP [('it', 'PRP')]
# NP [('it', 'PRP')]
# NP [('you', 'PRP')]
# NP [('An', 'DT'), ('iconic', 'JJ'), ('movie', 'NN')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: it's a man's romance.
# ===================================================================================
# NP [('one', 'CD'), ('our', 'PRP$')]
# NP [('two', 'CD'), ('fight', 'CD'), ('scenes', 'NNS')]
# NP [('it', 'PRP')]
# NP [('a', 'DT'), ('romance', 'NN')]
# NP [('O.k', 'NNP')]
# NP [('Sylvester', 'NNP-PERS'), ('Stallone', 'NNP-PERS')]
# NP [('the', 'DT'), ('star', 'NN')]
# NP [('this', 'DT'), ('movie', 'NN')]
# NP [('he', 'PRP')]
# NP [('a', 'DT'), ('t.u.f', 'NN'), ('guy', 'NN')]
# NP [('it', 'PRP')]
# NP [('him', 'PRP'), ('his', 'PRP$'), ('girl', 'NN'), ('friend', 'NN')]
# NP [('Sylvester', 'NNP-PERS'), ('Stallone', 'NNP-PERS')]
# NP [('star', 'NN')]
# NP [('this', 'DT'), ('movie', 'NN')]
# NP [('a', 'DT'), ('romance', 'NN'), ('movie', 'NN')]
# NP [('men', 'NNS')]
# NP [('Rocky', 'NNP'), ('II', 'NNP')]
# NP [('Rocky', 'NNP'), ('II', 'NNP')]
# NP [('It', 'PRP')]
# NP [('this', 'DT'), ('one', 'NN')]
# NP [('It', 'PRP')]
# NP [('Rocky', 'NNP'), ('III', 'NNP')]
# NP [('Rocky', 'NNP'), ('III', 'NNP')]
# NP [('Rocky', 'NNP'), ('III', 'NNP')]
# NP [('this', 'DT'), ('one', 'NN')]
# NP [('all', 'DT'), ('hype', 'NN')]
# NP [('It', 'PRP')]
# NP [('action', 'NN'), ('movie', 'NN')]
# NP [('It', 'PRP')]
# NP [('a', 'DT'), ('man', 'NN')]
# NP [('romance', 'NN')]
# NP [('many', 'JJ'), ('romance', 'NN'), ('movies', 'NNS')]
# NP [('hype', 'NN'), ('hype', 'NN'), ('hype', 'NN')]
# NP [('no', 'DT'), ('action', 'NN')]
# NP [('Sports', 'NNS')]
# NP [('Action', 'NNP')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: an iconic film
# ===================================================================================
# NP [('Rocky', 'NNP')]
# NP [('a', 'DT'), ('film', 'NN')]
# NP [('a', 'DT'), ('boxer', 'NN')]
# NP [('ultimate', 'JJ'), ('levels', 'NNS')]
# NP [('a', 'DT'), ('champion', 'NN')]
# NP [('the', 'DT'), ('ring', 'NN')]
# NP [('the', 'DT'), ('way', 'NN')]
# NP [('he', 'PRP')]
# NP [('confidence', 'NN')]
# NP [('a', 'DT'), ('young', 'JJ'), ('woman', 'NN')]
# NP [('him', 'PRP'), ('the', 'DT'), ('strength', 'NN')]
# NP [('he', 'PRP')]
# NP [('a', 'DT'), ('story', 'NN')]
# NP [('endurance', 'NN')]
# NP [('it', 'PRP')]
# NP [('films', 'NNS')]
# NP [('all', 'DT'), ('time', 'NN')]
# NP [('the', 'DT'), ('line', 'NN')]
# NP [('Yo', 'NNP')]
# NP [('Adrian', 'NNP')]
# NP [('I', 'PRP')]
# NP [('it', 'PRP')]
# NP [('the', 'DT'), ('famous', 'JJ'), ('clips', 'NNS')]
# NP [('Rocky', 'NNP')]
# NP [('exercise', 'NN')]
# NP [('his', 'PRP$'), ('endurance', 'NN')]
# NP [('the', 'DT'), ('Rocky', 'NNP'), ('theme', 'NN')]
# NP [('Gonna', 'NN')]
# NP [('The', 'DT'), ('story', 'NN')]
# NP [('a', 'DT'), ('little', 'JJ'), ('bit', 'NN')]
# NP [('those', 'DT'), ('moments', 'NNS')]
# NP [('a', 'DT'), ('bad', 'JJ'), ('film', 'NN')]
# NP [('it', 'PRP')]
# NP [('a', 'DT'), ('good', 'JJ'), ('choice', 'NN')]
# NP [('music', 'NN')]
# NP [('you', 'PRP'), ('a', 'DT'), ('sense', 'NN')]
# NP [('hope', 'NN')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: Good to watch
# ===================================================================================
# NP [('This', 'DT'), ('movie', 'NN')]
# NP [('I', 'PRP')]
# NP [('it', 'PRP')]
# NP [('parts', 'NNS')]
# NP [('your', 'PRP$'), ('love', 'NN'), ('life', 'NN')]
# NP [('All', 'DT'), ('I', 'PRP')]
# NP [('the', 'DT'), ('fight', 'NN')]
# NP [('More', 'JJR'), ('fight', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('us', 'PRP')]
# NP [('your', 'PRP$'), ('love', 'NN'), ('life', 'NN')]
# NP [('We', 'PRP')]
# NP [('Grade...4', 'NNP')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: Builds character rather than spectacle, but isn't quite as gripping as you'd expect.
# ===================================================================================
# NP [('a', 'DT'), ('chance', 'NN')]
# NP [('type', 'NN'), ('film', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('realistic', 'JJ'), ('stuff', 'NN')]
# NP [('its', 'PRP$'), ('focus', 'NN')]
# NP [('character', 'NN')]
# NP [('an', 'DT'), ('empathetic', 'JJ'), ('underdog', 'NN')]
# NP [('overt', 'JJ'), ('spectacle', 'NN')]
# NP [('something', 'NN')]
# NP [('the', 'DT'), ('sequels', 'NNS')]
# NP [('struggle', 'NN')]
# NP [('it', 'PRP')]
# NP [('a', 'DT'), ('bit', 'NN')]
# NP [('the', 'DT'), ('point', 'NN')]
# NP [('that', 'WDT'), ('the', 'DT'), ('final', 'JJ'), ('bout', 'NN')]
# NP [('the', 'DT'), ('piece', 'NN')]
# NP [('highlights', 'NNS')]
# NP [('a', 'DT'), ('miss', 'JJ'), ('passing', 'NN')]
# NP [('a', 'DT'), ('hit', 'NN')]
# NP [('a', 'DT'), ('big', 'JJ'), ('issue', 'NN')]
# NP [('the', 'DT'), ('flick', 'NN')]
# NP [('the', 'DT'), ('fact', 'NN')]
# NP [('the', 'DT'), ('preceding', 'JJ'), ('film', 'NN')]
# NP [('a', 'DT'), ('bit', 'NN')]
# NP [('a', 'DT'), ('drag', 'NN')]
# NP [('Stallone', 'NNP')]
# NP [('dialogue', 'NN')]
# NP [('a', 'DT'), ('problem', 'NN')]
# NP [('It', 'PRP')]
# NP [('any', 'DT'), ('stretch', 'NN')]
# NP [('it', 'PRP')]
# NP [('gripping', 'NN')]
# NP [('it', 'PRP')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: I Don't Get It
# ===================================================================================
# NP [('I', 'PRP')]
# NP [('Rocky', 'NNP')]
# NP [('last', 'JJ'), ('night', 'NN')]
# NP [('the', 'DT'), ('first', 'JJ'), ('time', 'NN')]
# NP [('guilt', 'NN')]
# NP [('it', 'PRP')]
# NP [('It', 'PRP')]
# NP [('the', 'DT'), ('other', 'JJ'), ('great', 'JJ'), ('films', 'NNS')]
# NP [('decade', 'NN')]
# NP [('film', 'NN'), ('history', 'NN')]
# NP [('I', 'PRP')]
# NP [('I', 'PRP')]
# NP [('something', 'NN')]
# NP [('I', 'PRP')]
# NP [('I', 'PRP')]
# NP [('it', 'PRP')]
# NP [('all', 'PDT'), ('the', 'DT'), ('other', 'JJ'), ('countless', 'JJ'), ('underdog-rises-to-the-challenge', 'JJ'), ('films', 'NNS')]
# NP [('me', 'PRP')]
# NP [('It', 'PRP')]
# NP [('a', 'DT'), ('fine', 'JJ'), ('little', 'JJ'), ('movie', 'NN')]
# NP [('slo-o-o-o-w', 'NN')]
# NP [('I', 'PRP')]
# NP [('it', 'PRP')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: My dad forced me to watch it
# ===================================================================================
# NP [('my', 'PRP$'), ('father', 'NN')]
# NP [('us', 'PRP')]
# NP [('the', 'DT'), ('movie', 'NN'), ('we', 'PRP')]
# NP [('He', 'PRP')]
# NP [('it', 'PRP'), ('way', 'NN')]
# NP [('his', 'PRP$'), ('mind', 'NN')]
# NP [('that', 'WDT'), ('it', 'PRP')]
# NP [('It', 'PRP')]
# NP [('the', 'DT'), ('suspense', 'NN')]
# NP [('Either', 'JJ'), ('way', 'NN')]
# NP [('the', 'DT'), ('camera', 'NN')]
# NP [('nice', 'JJ'), ('pictures', 'NNS')]
# NP [('the', 'DT'), ('background', 'NN'), ('story', 'NN')]
# NP [('Sylvester', 'NNP-PERS'), ('Stallone', 'NNP-PERS')]
# NP [('the', 'DT'), ('studios', 'NNS')]
# NP [('his', 'PRP$'), ('film', 'NN')]
# NP [('conclusion', 'NN')]
# NP [('16', 'CD'), ('years', 'NNS')]
# NP [('it', 'PRP')]
# NP [('the', 'DT'), ('picture', 'NN'), ('quality', 'NN')]
# NP [('the', 'DT'), ('background', 'NN'), ('story', 'NN')]
# NP [('The', 'DT'), ('story', 'NN')]
# NP [('you', 'PRP')]
# NP [('the', 'DT'), ('film', 'NN')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: Popular melodrama in a landmark era for American cinema
# ===================================================================================
# NP [('A', 'DT'), ('landmark', 'NN'), ('year', 'NN')]
# NP [('cinema', 'NN')]
# NP [('Academy', 'NNP'), ('awards', 'NNS')]
# NP [('history', 'NN')]
# NP [('No', 'DT'), ('matter', 'NN')]
# NP [('you', 'PRP')]
# NP [('it', 'PRP')]
# NP [('the', 'DT'), ('greatest', 'JJS'), ('time', 'NN')]
# NP [('American', 'JJ'), ('cinema', 'NN')]
# NP [('Scorsese', 'NNP')]
# NP [('Coppola', 'NNP')]
# NP [('Lumet', 'NNP')]
# NP [('the', 'DT'), ('fiercest', 'JJS'), ('battles', 'NNS')]
# NP [('the', 'DT'), ('Academy', 'NNP'), ('awards', 'NNS')]
# NP [('it', 'PRP')]
# NP [('an', 'DT'), ('exciting', 'JJ'), ('time', 'NN')]
# NP [('moviegoers', 'NNS')]
# NP [('Rocky', 'NNP')]
# NP [('a', 'DT'), ('bad', 'JJ'), ('rap', 'NN')]
# NP [('beating', 'NN')]
# NP [('these', 'DT'), ('American', 'JJ'), ('classics', 'NNS')]
# NP [('the', 'DT'), ('prize', 'NN')]
# NP [('the', 'DT'), ('fact', 'NN')]
# NP [('it', 'PRP')]
# NP [('a', 'DT'), ('powerful', 'JJ'), (',', ','), ('inspirational', 'JJ'), ('film', 'NN')]
# NP [('a', 'DT'), ('man', 'NN')]
# NP [('dreams', 'NNS')]
# NP [('no', 'DT'), ('matter', 'NN')]
# NP [('obstacles', 'NNS')]
# NP [('his', 'PRP$'), ('way', 'NN')]
# NP [('The', 'DT'), ('question', 'NN')]
# NP [('it', 'PRP')]
# NP [('30', 'CD'), ('years', 'NNS')]
# NP [('The', 'DT'), ('character', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('the', 'DT'), ('most', 'RBS'), ('memorable', 'JJ'), ('film', 'NN'), ('characters', 'NNS')]
# NP [('Stallone', 'NNP')]
# NP [('a', 'DT'), ('serious', 'JJ'), ('filmmaker', 'NN')]
# NP [('the', 'DT'), ('sequences', 'NNS')]
# NP [('film', 'NN'), ('and', 'CC'), ('popular', 'JJ'), ('culture', 'NN')]
# NP [('the', 'DT'), ('training', 'NN'), ('sessions', 'NNS')]
# NP [('meat', 'NN'), ('boxing', 'NN'), ('and', 'CC'), ('the', 'DT'), ('final', 'JJ'), ('battle', 'NN')]
# NP [('scenes', 'NNS')]
# NP [('fans', 'NNS')]
# NP [('these', 'DT'), ('scenes', 'NNS')]
# NP [('great', 'JJ'), ('emotional', 'JJ'), ('instability', 'NN')]
# NP [('no', 'DT'), ('matter', 'NN')]
# NP [('clichéd', 'NN'), ('they', 'PRP')]
# NP [('today', 'NN')]
# NP [('one', 'NN')]
# NP [('the', 'DT'), ('greatest', 'JJS'), ('underdog', 'NN'), ('stories', 'NNS')]
# NP [('Stallone', 'NNP')]
# NP [('the', 'DT'), ('film', 'NN')]
# NP [('it', 'PRP')]
# NP [('duration', 'NN')]
# NP [('no', 'RB'), ('other', 'JJ'), ('actor', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('The', 'DT'), ('character', 'NN')]
# NP [('Stallone', 'NNP')]
# NP [('the', 'DT'), ('screenplay', 'NN')]
# NP [('Oscar', 'NNP'), ('nominated', 'NN')]
# NP [('both', 'DT'), ('his', 'PRP$'), ('acting', 'NN')]
# NP [('writing', 'NN')]
# NP [('Stallone', 'NNP')]
# NP [('mannerisms', 'NNS')]
# NP [('dopey', 'NN')]
# NP [('style', 'NN')]
# NP [('the', 'DT'), ('character', 'NN')]
# NP [('a', 'DT'), ('glove', 'NN')]
# NP [('The', 'DT'), ('writing', 'NN')]
# NP [('I', 'PRP')]
# NP [('issues', 'NNS')]
# NP [('the', 'DT'), ('film', 'NN')]
# NP [('a', 'DT'), ('bit', 'NN')]
# NP [('You', 'PRP')]
# NP [('Stallone', 'NNP')]
# NP [('himself', 'PRP'), ('but', 'CC'), ('he', 'PRP')]
# NP [('a', 'DT'), ('good', 'JJ'), ('job', 'NN')]
# NP [('The', 'DT'), ('other', 'JJ'), ('strength', 'NN')]
# NP [('the', 'DT'), ('film', 'NN')]
# NP [('the', 'DT'), ('directing', 'NN')]
# NP [('which', 'WDT'), ('it', 'PRP')]
# NP [('an', 'DT'), ('Oscar', 'NNP')]
# NP [('It', 'PRP')]
# NP [('the', 'DT'), ('Rocky', 'NNP')]
# NP [('neighbourhood', 'NN')]
# NP [('the', 'DT'), ('missed', 'JJ'), ('opportunities', 'NNS')]
# NP [('the', 'DT'), ('darkness', 'NN')]
# NP [('hope', 'NN')]
# NP [('The', 'DT'), ('shades', 'NNS')]
# NP [('a', 'DT'), ('dream', 'NN')]
# NP [('light', 'NN')]
# NP [('patient', 'NN')]
# NP [('a', 'DT'), ('orthodox', 'JJ'), ('story', 'NN')]
# NP [('favour', 'NN')]
# NP [('the', 'DT'), ('director', 'NN')]
# NP [('I', 'PRP')]
# NP [('this', 'DT'), ('film', 'NN')]
# NP [('I', 'PRP')]
# NP [('the', 'DT'), ('story', 'NN')]
# NP [('clichéd', 'NN')]
# NP [('light', 'NN')]
# NP [('this', 'DT'), ('30', 'CD'), ('years', 'NNS')]
# NP [('it', 'PRP')]
# NP [('release', 'NN')]
# NP [('hindsight', 'NN')]
# NP [('more', 'JJR'), ('recent', 'JJ'), ('boxing', 'NN'), ('films', 'NNS')]
# NP [('some', 'DT'), ('dead', 'JJ'), ('moments', 'NNS')]
# NP [('I', 'PRP')]
# NP [('the', 'DT'), ('fight', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('soap', 'NN'), ('operatic', 'JJ'), ('antics', 'NNS')]
# NP [('his', 'PRP$'), ('girlfriend', 'NN'), ('and', 'CC'), ('family', 'NN')]
# NP [('the', 'DT'), ('end', 'NN'), ('I', 'PRP')]
# NP [('it', 'PRP')]
# NP [('me', 'PRP')]
# NP [('I', 'PRP')]
# NP [('it', 'PRP')]
# NP [('music', 'NN'), ('and', 'CC'), ('story', 'NN')]
# NP [('Plus', 'JJ'), ('it', 'PRP')]
# NP [('the', 'DT'), ('other', 'JJ'), ('American', 'JJ'), ('films', 'NNS')]
# NP [('this', 'DT'), ('era', 'NN')]
# NP [('a', 'DT'), ('comment', 'NN')]
# NP [('American', 'JJ'), ('life', 'NN')]
# NP [('the', 'DT'), ('dream', 'NN')]
# NP [('All', 'PDT'), ('the', 'DT'), ('President', 'NNP')]
# NP [('Men', 'NN')]
# NP [('Taxi', 'NN'), ('Driver', 'NNP')]
# NP [('Network', 'NNP'), ('and', 'CC'), ('Raging', 'NNP'), ('Bull', 'NNP')]
# NP [('All', 'PDT'), ('these', 'DT'), ('films', 'NNS')]
# NP [('something', 'NN')]
# NP [('hopes', 'NNS')]
# NP [('dreams', 'NNS')]
# NP [('ideals', 'NNS')]
# NP [('Rocky', 'NNP')]
# NP [('the', 'DT'), ('hearts', 'NNS')]
# NP [('the', 'DT'), ('viewers', 'NNS')]
# NP [('it', 'PRP')]
# NP [('contemporaries', 'NNS')]
# NP [('today', 'NN')]
# NP [('world', 'NN')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: Schlocky
# ===================================================================================
# NP [('The', 'DT'), ('most', 'RBS'), ('memorable', 'JJ'), ('moment', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('the', 'DT'), ('love-scene', 'NN')]
# NP [('Adrian', 'NNP')]
# NP [('the', 'DT'), ('otherwise', 'RB'), ('fetid', 'JJ'), ('room', 'NN')]
# NP [('such', 'JJ'), ('clean', 'JJ'), ('passion', 'NN')]
# NP [('it', 'PRP')]
# NP [('all', 'DT'), ('cardinal', 'JJ'), ('passions', 'NNS')]
# NP [('Adrian', 'NNP')]
# NP [('an', 'DT'), ('act', 'NN'), ('shy', 'NN')]
# NP [('slow', 'JJ'), ('excitement', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('kisses', 'NNS')]
# NP [('love', 'NN')]
# NP [('weaknesses', 'NNS')]
# NP [('The', 'DT'), ('problem', 'NN')]
# NP [('the', 'DT'), ('best', 'JJS'), ('scene', 'NN')]
# NP [('the', 'DT'), ('movie', 'NN')]
# NP [('the', 'DT'), ("'", 'CD'), ('action', 'NN')]
# NP [('sport', 'NN')]
# NP [('This', 'DT'), ('kind', 'NN')]
# NP [('movies', 'NNS')]
# NP [('Rocky', 'NNP')]
# NP [('me', 'PRP')]
# NP [('a', 'DT'), ('sweet', 'JJ'), ('romance', 'NN')]
# NP [('an', 'DT'), ('action', 'NN')]
# NP [('an', 'DT'), ('underdog', 'NN'), ('story', 'NN')]
# NP [('It', 'PRP')]
# NP [('Boxing', 'NN'), ('Practice', 'NNP')]
# NP [('Rule', 'NN')]
# NP [('Gulp', 'NN')]
# NP [('six', 'CD'), ('raw', 'JJ'), ('eggs', 'NNS'), ('Rule', 'NN')]
# NP [('Jog', 'NNP'), ('a', 'DT'), ('mile', 'NN')]
# NP [('I', 'PRP')]
# NP [('Million', 'CD'), ('Dollar', 'NNP'), ('Baby', 'NNP')]
# NP [('its', 'PRP$'), ('guts', 'NNS')]
# NP [('its', 'PRP$'), ('balance', 'NN')]
# NP [('action', 'NN'), ('and', 'CC'), ('drama', 'NN')]
# NP [('The', 'DT'), ('second', 'JJ'), ('half', 'NN')]
# NP [('I', 'PRP')]
# NP [('it', 'PRP')]
# NP [('the', 'DT'), ('end', 'NN')]
# NP [('my', 'PRP$'), ('eyes', 'NNS')]
# NP [('Rocky', 'NNP')]
# NP [('such', 'PDT'), ('a', 'DT'), ('film', 'NN')]
# NP [('it', 'PRP')]
# NP [('pretense', 'NN')]
# NP [('The', 'DT'), ('movie', 'NN')]
# NP [('I', 'PRP')]
# NP [('the', 'DT'), ('accent', 'NN')]
# NP [('the', 'DT'), ('caricature', 'NN')]
# NP [('The', 'DT'), ('opening', 'JJ'), ('scene', 'NN')]
# NP [('a', 'DT'), ('normal', 'JJ'), ('boxing', 'NN'), ('match', 'NN')]
# NP [('the', 'DT'), ('brawny', 'JJ'), ('Stallone', 'NNP')]
# NP [('another', 'DT'), ('unknown', 'JJ'), ('face', 'NN')]
# NP [('A', 'DT'), ('small-time', 'JJ'), ('boxer', 'NN')]
# NP [('a', 'DT'), ('collector', 'NN')]
# NP [('Gazzo', 'NNP')]
# NP [('he', 'PRP')]
# NP [('an', 'DT'), ('ordinary', 'JJ'), ('life', 'NN')]
# NP [('loving', 'JJ'), ('his', 'PRP$'), ('pets', 'NNS')]
# NP [('a', 'DT'), ('painfully', 'RB'), ('shy', 'JJ'), ('girl', 'NN')]
# NP [('an', 'DT'), ('androgynous', 'JJ'), ('girl', 'NN'), ('lessons', 'NNS')]
# NP [('His', 'PRP$'), ('preference', 'NN')]
# NP [('the', 'DT'), ('conversation', 'NN')]
# NP [('he', 'PRP')]
# NP [('her', 'PRP')]
# NP [('a', 'DT'), ('foul-mouthed', 'JJ'), ('girl', 'NN')]
# NP [('nothing', 'NN')]
# NP [('future', 'NN')]
# NP [('a', 'DT'), ('lady', 'NN')]
# NP [('his', 'PRP$'), ('wife', 'NN')]
# NP [('which', 'WDT'), ('he', 'PRP'), ('notices', 'NNS')]
# NP [('Adrian', 'NNP')]
# NP [('This', 'DT'), ('small-timer', 'NN')]
# NP [('a', 'DT'), ('pedestal', 'NN')]
# NP [('he', 'PRP')]
# NP [('an', 'DT'), ('opportunity', 'NN')]
# NP [('world-champion', 'NN'), ('Apollo', 'NNP'), ('Creed', 'NNP')]
# NP [('this', 'DT'), ('all', 'NN')]
# NP [('good', 'JJ'), ('show', 'NN')]
# NP [('Sylvester', 'NNP')]
# NP [('inkling', 'NN')]
# NP [('he', 'PRP')]
# NP [('I', 'PRP')]
# NP [('any', 'DT'), ('vigor', 'NN')]
# NP [('his', 'PRP$'), ('eyes', 'NNS')]
# NP [('his', 'PRP$'), ('eyes', 'NNS')]
# NP [('the', 'DT'), ('scene', 'NN')]
# NP [('he', 'PRP'), ('vents', 'NNS')]
# NP [('his', 'PRP$'), ('frustration', 'NN')]
# NP [('his', 'PRP$'), ('to-be', 'JJ'), ('trainer', 'NN')]
# NP [('faith', 'NN')]
# NP [('him', 'PRP')]
# NP [('he', 'PRP')]
# NP [('the', 'DT'), ('line', 'NN')]
# NP [('them', 'PRP')]
# NP [('it', 'PRP')]
# NP [('voice', 'NN')]
# NP [('that', 'WDT'), ('he', 'PRP')]
# NP [('the', 'DT'), ('script', 'NN')]
# NP [('a', 'DT'), ('shade', 'NN')]
# NP [('humor', 'NN')]
# NP [('it', 'PRP')]
# NP [('the', 'DT'), ('end', 'NN')]
# NP [('a', 'DT'), ('screenwriter', 'NN')]
# NP [('The', 'DT'), ('choreography', 'NN')]
# NP [('the', 'DT'), ('boxing', 'NN'), ('sequences', 'NNS')]
# NP [('anything', 'NN')]
# NP [('it', 'PRP'), ('never', 'RB'), ('gains', 'NNS'), ('steam', 'NN')]
# NP [('The', 'DT'), ('climatic', 'JJ'), ('boxing', 'NN'), ('scene', 'NN')]
# NP [('professional', 'JJ'), ('help', 'NN')]
# NP [('these', 'DT'), ('sequences', 'NNS')]
# NP [('writing', 'NN'), ('it', 'PRP'), ('himself', 'PRP')]
# NP [('Talia', 'NNP')]
# NP [('taciturn', 'NN'), ('girl-friend', 'NN')]
# NP [('the', 'DT'), ('scenes', 'NNS')]
# NP [('I', 'PRP')]
# NP [('her', 'PRP')]
# NP [('I', 'PRP'), ('myself', 'PRP')]
# NP [('person', 'NN')]
# NP [('bouts', 'NNS')]
# NP [('hysterics', 'NNS')]
# NP [('The', 'DT'), ('most', 'RBS'), ('captivating', 'JJ'), ('quality', 'NN')]
# NP [('Talia', 'NNP')]
# NP [('a', 'DT'), ('way', 'NN')]
# NP [('untold', 'JJ'), ('emotions', 'NNS')]
# NP [('Her', 'PRP$'), ('character', 'NN')]
# NP [('the', 'DT'), ('end', 'NN')]
# NP [('she', 'PRP')]
# NP [('the', 'DT'), ('heroine', 'NN')]
# NP [('Grease', 'NN')]
# NP [('her', 'PRP$'), ('love', 'NN')]
# NP [('the', 'DT'), ('end', 'NN')]
# NP [('Others', 'NNS')]
# NP [('the', 'DT'), ('movie', 'NN')]
# NP [('Burt', 'NNP'), ('Young', 'NNP')]
# NP [('the', 'DT'), ('crass', 'JJ'), (',', ','), ('resentful', 'JJ'), ('but', 'CC'), ('attention-seeking', 'JJ'), (',', ','), ('insecure', 'JJ'), ('brother', 'NN')]
# NP [('Adrian', 'NNP')]
# NP [('Burgess', 'NNP')]
# NP [('the', 'DT'), ('surly', 'JJ'), ('coach', 'NN')]
# NP [('a', 'DT'), ('story', 'NN')]
# NP [('failure', 'NN')]
# NP [('the', 'DT'), ('past', 'NN')]
# NP [('His', 'PRP$')]
# NP [('Rocky', 'NNP')]
# NP [('chants', 'NNS')]
# NP [('such', 'JJ'), ('character', 'NN')]
# NP [('a', 'DT'), ('college', 'NN'), ('movie', 'NN')]
# NP [('unruly', 'JJ'), ('youngsters', 'NNS')]
# NP [('Grease', 'NN')]
# NP [('Carl', 'NNP'), ('Weathers', 'NNPS')]
# NP [('character', 'NN'), ('Apollo', 'NNP')]
# NP [('me', 'PRP')]
# NP [('Lady', 'NNP-PERS'), ('Gaga', 'NNP-PERS')]
# NP [('he', 'PRP')]
# NP [('a', 'DT'), ('friendly', 'JJ'), ('villain', 'NN')]
# NP [('a', 'DT'), ('contrast', 'NN')]
# NP [('other', 'JJ'), ('sports', 'NNS'), ('movies', 'NNS')]
# NP [('I', 'PRP')]
# NP [('the', 'DT'), ('old-fashioned', 'JJ'), ('ones', 'NNS')]
# NP [('a', 'DT'), ('figure', 'NN')]
# NP [('The', 'DT'), ('story', 'NN')]
# NP [('times', 'NNS')]
# NP [('a', 'DT'), ('broken', 'JJ'), ('tooth', 'NN')]
# NP [('dislocated', 'JJ'), ('shoulder', 'NN')]
# NP [('the', 'DT'), ('middle', 'NN')]
# NP [('Two', 'CD'), ('fights', 'NNS')]
# NP [('a', 'DT'), ('classic', 'JJ'), ('sports', 'NNS'), ('film', 'NN')]
# NP [('The', 'DT'), ('direction', 'NN')]
# NP [('schmaltzy', 'NN')]
# NP [('multiple', 'JJ'), ('places', 'NNS')]
# NP [('The', 'DT'), ('background', 'NN'), ('score', 'NN')]
# NP [('some', 'DT'), ('potential', 'JJ'), ('hits', 'NNS')]
# NP [('effect', 'NN')]
# NP [('you', 'PRP')]
# NP [('the', 'DT'), ('end', 'NN')]
# NP [('the', 'DT'), ('tight', 'JJ'), ('budget', 'NN')]
# NP [('these', 'DT'), ('slights', 'NNS')]
# NP [('films', 'NNS')]
# NP [('shoe-string', 'NN'), ('budget', 'NN')]
# NP [('next', 'JJ'), ('time', 'NN')]
# NP [('Talia', 'NNP')]
# NP [('Sly', 'NNP')]
# NP [('more', 'JJR'), ('action', 'NN')]
# NP [('May', 'NNP'), ('watch', 'NN')]
# NP [('the', 'DT'), ('sequel', 'NN')]
# NP [('I', 'PRP')]
# NP [('I', 'PRP')]
# NP [('it', 'PRP')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: The Loser
# ===================================================================================
# NP [('I', 'PRP')]
# NP [('a', 'DT'), ('variety', 'NN')]
# NP [('reasons', 'NNS')]
# NP [('the', 'DT'), ('scale', 'NN')]
# NP [('ring', 'NN')]
# NP [('movies', 'NNS')]
# NP [('The', 'DT'), ('Wrestler', 'NNP')]
# NP [('The', 'DT'), ('reason', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('the', 'DT'), ('camera', 'NN')]
# NP [('the', 'DT'), ('ring', 'NN'), ('business', 'NN')]
# NP [('I', 'PRP')]
# NP [('it', 'PRP')]
# NP [('the', 'DT'), ('very', 'RB'), ('first', 'JJ'), ('movie', 'NN')]
# NP [('a', 'DT'), ('way', 'NN')]
# NP [('you', 'PRP')]
# NP [('the', 'DT'), ('fight', 'NN')]
# NP [('you', 'PRP')]
# NP [('the', 'DT'), ('cinematic', 'JJ'), ('space', 'NN')]
# NP [('all', 'DT'), ('his', 'PRP$')]
# NP [('many', 'JJ'), ('faults', 'NNS')]
# NP [('an', 'DT'), ('amazing', 'JJ'), ('job', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('clarity', 'NN')]
# NP [('the', 'DT'), ('dullness', 'NN')]
# NP [('the', 'DT'), ('Rocky', 'NNP'), ('character', 'NN')]
# NP [('the', 'DT'), ('way', 'NN')]
# NP [('Bull', 'NNP')]
# NP [('a', 'DT'), ('new', 'JJ'), ('standard', 'NN')]
# NP [('the', 'DT'), ('ring', 'NN')]
# NP [('camera-work', 'NN')]
# NP [('a', 'DT'), ('new', 'JJ'), ('vocabulary', 'NN')]
# NP [('any', 'DT'), ('two', 'CD'), ('characters', 'NNS')]
# NP [('Those', 'DT'), ('360', 'NNP')]
# NP [('two', 'CD'), ('folks', 'NNS')]
# NP [('something', 'NN')]
# NP [('them', 'PRP')]
# NP [('the', 'DT'), ('lowest', 'JJS'), ('form', 'NN')]
# NP [('two', 'CD'), ('competent', 'JJ'), ('folks', 'NNS')]
# NP [('I', 'PRP')]
# NP [('I', 'PRP')]
# NP [('Rocky', 'NNP')]
# NP [('I', 'PRP')]
# NP [('the', 'DT'), ('whole', 'JJ'), ('series', 'NN')]
# NP [('we', 'PRP')]
# NP [('the', 'DT'), ('time', 'NN')]
# NP [('reality', 'NN')]
# NP [('the', 'DT'), ('story', 'NN')]
# NP [('Stallone', 'NNP')]
# NP [('story', 'NN')]
# NP [('his', 'PRP$'), ('romance', 'NN')]
# NP [('a', 'DT'), ('Copolla', 'NNP')]
# NP [('It', 'PRP')]
# NP [('we', 'PRP')]
# NP [('film', 'NN')]
# NP [('a', 'DT'), ('steadicam', 'NN')]
# NP [('the', 'DT'), ('steps', 'NNS')]
# NP [('them', 'PRP')]
# NP [('the', 'DT'), ('ring', 'NN')]
# NP [('the', 'DT'), ('time', 'NN'), ('it', 'PRP')]
# NP [('it', 'PRP')]
# NP [('we', 'PRP')]
# NP [('the', 'DT'), ('now', 'RB'), ('sharper', 'JJR'), ('knowledge', 'NN')]
# NP [('reality', 'NN')]
# NP [('the', 'DT'), ('fiction', 'NN')]
# NP [('the', 'DT'), ('story', 'NN')]
# NP [('course', 'NN')]
# NP [('me', 'PRP')]
# NP [('that', 'DT'), ('overlapping', 'NN')]
# NP [('everything', 'NN')]
# NP [('Pay', 'JJ'), ('attention', 'NN')]
# NP [('the', 'DT'), ('dialog', 'NN')]
# NP [('every', 'DT'), ('word', 'NN')]
# NP [('Stallone', 'NNP')]
# NP [('rich', 'JJ'), ('his', 'PRP$')]
# NP [('own', 'JJ'), ('speeches', 'NNS')]
# NP [('trite', 'JJ'), ('speeches', 'NNS')]
# NP [('others', 'NNS')]
# NP [('an', 'DT'), ('adventure', 'NN')]
# NP [('me', 'PRP')]
# NP [('the', 'DT'), ('Rocky', 'NNP')]
# NP [('Rambo', 'NNP'), ('stuff', 'NN')]
# NP [('I', 'PRP')]
# NP [('Stallone', 'NNP')]
# NP [('Ted', 'NNP')]
# NP [('Evaluation', 'NN')]
# NP [('some', 'DT'), ('interesting', 'JJ'), ('elements', 'NNS')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: A triumph of self-pitying losers
# ===================================================================================
# NP [('I', 'PRP')]
# NP [('the', 'DT'), ('story', 'NN')]
# NP [('the', 'DT'), ('creation', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('the', 'DT'), ('fact', 'NN')]
# NP [('Stallone', 'NNP')]
# NP [('a', 'DT'), ('very', 'RB'), ('hard', 'JJ'), ('time', 'NN')]
# NP [('the', 'DT'), ('studios', 'NNS')]
# NP [('attention', 'NN')]
# NP [('the', 'DT'), ('screenplay', 'NN')]
# NP [('his', 'PRP$'), ('vision', 'NN')]
# NP [('a', 'DT'), ('chance', 'NN')]
# NP [('the', 'DT'), ('obscurity', 'NN'), ('his', 'PRP$'), ('career', 'NN')]
# NP [('himself', 'PRP')]
# NP [('that', 'DT'), ('time', 'NN')]
# NP [('we', 'PRP')]
# NP [('Rocky', 'NNP')]
# NP [('moment', 'NN')]
# NP [('the', 'DT'), ('Stallone', 'NNP')]
# NP [('star', 'NN')]
# NP [('it', 'PRP')]
# NP [('a', 'DT'), ('pretty', 'JJ'), ('important', 'JJ'), ('film', 'NN')]
# NP [('i', 'NNS')]
# NP [('a', 'DT'), ('film', 'NN')]
# NP [('merits', 'NNS')]
# NP [('career', 'NN'), ('it', 'PRP')]
# NP [('a', 'DT'), ('separate', 'JJ'), ('cinematographic', 'JJ'), ('product', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('the', 'DT'), ('best', 'JJS'), ('films', 'NNS')]
# NP [('all', 'DT'), ('times', 'NNS')]
# NP [('it', 'PRP')]
# NP [('plain', 'JJ'), ('average', 'NN')]
# NP [('The', 'DT'), ('whole', 'JJ'), ('fiber', 'NN')]
# NP [('the', 'DT'), ('film', 'NN')]
# NP [('hopelessness', 'NN'), ('and', 'CC'), ('despair', 'NN')]
# NP [('Philadelphia', 'NNP-LOC')]
# NP [('a', 'DT'), ('grim', 'JJ'), ('place', 'NN')]
# NP [('the', 'DT'), ('main', 'JJ'), ('reason', 'NN')]
# NP [('a', 'DT'), ('story', 'NN')]
# NP [('a', 'DT'), ('depressing', 'JJ'), ('environment', 'NN')]
# NP [('the', 'DT'), ('life', 'NN')]
# NP [('Rocky', 'NNP'), ('Balboa', 'NNP')]
# NP [('him', 'PRP')]
# NP [('some', 'DT'), ('kind', 'NN')]
# NP [('a', 'DT'), ('Cinderella', 'NNP'), ('story', 'NN')]
# NP [('us', 'PRP'), ('root', 'NN')]
# NP [('the', 'DT'), ('underdog', 'NN')]
# NP [('it', 'PRP')]
# NP [('Rocky', 'NNP')]
# NP [('Stallone', 'NNP')]
# NP [('script', 'NN')]
# NP [('its', 'PRP$')]
# NP [('the', 'DT'), ('audience', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('The', 'DT'), ('first', 'JJ'), ('half', 'NN')]
# NP [('the', 'DT'), ('film', 'NN')]
# NP [('a', 'DT'), ('showcase', 'NN')]
# NP [('a', 'DT'), ('bum', 'NN')]
# NP [('a', 'DT'), ('true', 'JJ'), ('imbecile', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('some', 'DT'), ('deranged', 'JJ'), ('nonsense', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('Frankenstein', 'NNP')]
# NP [('Cinderella', 'NNP')]
# NP [('the', 'DT'), ('murky', 'JJ'), ('streets', 'NNS')]
# NP [('the', 'DT'), ('Philadelphia', 'NNP-LOC'), ('slums', 'NNS')]
# NP [('any', 'DT'), ('idea', 'NN')]
# NP [('his', 'PRP$'), ('life', 'NN'), ('today', 'NN')]
# NP [('it', 'PRP'), ('tomorrow', 'NN')]
# NP [('The', 'DT'), ('only', 'JJ'), ('way', 'NN')]
# NP [('him', 'PRP')]
# NP [('him', 'PRP'), ('pet', 'JJ'), ('turtles', 'NNS')]
# NP [('an', 'DT'), ('affection', 'NN')]
# NP [('emotionally', 'RB'), ('disabled', 'JJ'), ('woman', 'NN')]
# NP [('a', 'DT'), ('store', 'NN')]
# NP [('me', 'PRP')]
# NP [('the', 'DT'), ('Cinderella', 'NNP'), ('story', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('an', 'DT'), ('invitation', 'NN')]
# NP [('a', 'DT'), ('ball', 'NN')]
# NP [('A', 'DT'), ('title', 'NN'), ('boxing', 'NN'), ('fight', 'NN')]
# NP [('his', 'PRP$'), ('case', 'NN')]
# NP [('Balboa', 'NNP')]
# NP [('constant', 'JJ'), ('downer', 'NN')]
# NP [('attitude', 'NN')]
# NP [('an', 'DT'), ('example', 'NN')]
# NP [('You', 'PRP')]
# NP [('a', 'DT'), ('moron', 'NN')]
# NP [('a', 'DT'), ('fighter', 'NN')]
# NP [('you', 'PRP')]
# NP [('I', 'PRP')]
# NP [('It', 'PRP')]
# NP [('a', 'DT'), ('racket', 'NN')]
# NP [('you', 'PRP')]
# NP [('a', 'DT'), ('bum', 'NN')]
# NP [('the', 'DT'), ('film', 'NN')]
# NP [('some', 'DT'), ('room', 'NN')]
# NP [('that', 'DT'), ('change', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('it', 'PRP')]
# NP [('something', 'NN')]
# NP [('he', 'PRP')]
# NP [('The', 'DT'), ('end', 'NN')]
# NP [('this', 'DT'), ('fairy', 'JJ'), ('tale', 'NN')]
# NP [('it', 'PRP')]
# NP [('the', 'DT'), ('protagonist', 'NN')]
# NP [('It', 'PRP')]
# NP [('i', 'NNS'), ('guess', 'NN'), ('Stallone', 'NNP')]
# NP [('enough', 'JJ'), ('star', 'NN'), ('fever', 'NN')]
# NP [('his', 'PRP$'), ('character', 'NN')]
# NP [('the', 'DT'), ('fact', 'NN')]
# NP [('the', 'DT'), ('film', 'NN')]
# NP [('a', 'DT'), ('sign', 'NN')]
# NP [('the', 'DT'), ('author', 'NN')]
# NP [('no', 'DT'), ('idea', 'NN')]
# NP [('a', 'DT'), ('woman', 'NN')]
# NP [('the', 'DT'), ('rescue', 'NN')]
# NP [('the', 'DT'), ('impression', 'NN')]
# NP [('the', 'DT'), ('whole', 'JJ'), ('film', 'NN')]
# NP [('its', 'PRP$'), ('goals', 'NNS')]
# NP [('the', 'DT'), ('distance', 'NN')]
# NP [('no', 'RB'), ('much', 'JJ'), ('choice', 'NN')]
# NP [('the', 'DT'), ('audience', 'NN')]
# NP [('blind', 'JJ'), ('weary', 'JJ'), ('spirit', 'NN')]
# NP [('the', 'DT'), ('day', 'NN')]
# NP [('it', 'PRP')]
# NP [('the', 'DT'), ('success', 'NN')]
# NP [('Rocky', 'NNP'), ('and', 'CC'), ('the', 'DT'), ('career', 'NN')]
# NP [('Stallone', 'NNP'), ('itself', 'PRP')]
# NP [('nothing', 'NN'), ('but', 'CC'), ('freak', 'NN'), ('luck', 'NN')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: Good but nothing to remember!!!!!!
# ===================================================================================
# NP [('I', 'PRP')]
# NP [('Sylvester', 'NNP-PERS'), ('Stallone', 'NNP-PERS')]
# NP [('all', 'DT'), ('but', 'CC'), ('he', 'PRP')]
# NP [('two', 'CD'), ('good', 'JJ'), ('roles', 'NNS')]
# NP [('This', 'DT'), ('and', 'CC'), ('Cop', 'NNP'), ('land', 'NN')]
# NP [('sport', 'NN')]
# NP [('story', 'NN')]
# NP [('the', 'DT'), ('boxer', 'NN')]
# NP [('his', 'PRP$'), ('all', 'NN')]
# NP [('the', 'DT'), ('championship.The', 'JJ'), ('boxing', 'NN'), ('scenes', 'NNS')]
# NP [('nothing', 'NN')]
# NP [('you', 'PRP')]
# NP [('it', 'PRP')]
# NP [('the', 'DT'), ('start', 'NN')]
# NP [('the', 'DT'), ('film', 'NN')]
# NP [('a', 'DT'), ('heart', 'NN')]
# NP [('it´s', 'NN')]
# NP [('I', 'PRP')]
# NP [('the', 'DT'), ('other', 'JJ'), ('rocky', 'JJ'), ('films', 'NNS')]
# NP [('I', 'PRP')]
# NP [('some', 'DT'), ('parts', 'NNS')]
# NP [('the', 'DT'), ('other', 'JJ'), ('films', 'NNS')]
# NP [('cabel-tv', 'NN')]
# NP [('just', 'RB'), ('like', 'JJ'), ('trash', 'NN')]
# NP [('RATING:3/5', 'NNP')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky Review Title: Not that big of a deal
# ===================================================================================
# NP [('I', 'PRP')]
# NP [('those', 'DT'), ('this-film-is-overrated', 'JJ'), ('people', 'NNS')]
# NP [('the', 'DT'), ('case', 'NN')]
# NP [('this', 'DT'), ('film', 'NN')]
# NP [('this', 'DT'), ('film', 'NN')]
# NP [('the', 'DT'), ('first', 'JJ'), ('time', 'NN')]
# NP [('I', 'PRP')]
# NP [('a', 'DT'), ('lot', 'NN')]
# NP [('it', 'PRP')]
# NP [('I', 'PRP')]
# NP [('this', 'DT'), ('film', 'NN')]
# NP [('I', 'PRP')]
# NP [('it', 'PRP')]
# NP [('It', 'PRP')]
# NP [('a', 'DT'), ('good', 'JJ'), ('film', 'NN')]
# NP [('a', 'DT'), ('fairly', 'RB'), ('generic', 'JJ'), ('underdog', 'NN'), ('story', 'NN')]
# NP [('The', 'DT'), ('film', 'NN')]
# NP [('the', 'DT'), ('chemistry', 'NN')]
# NP [('Rocky', 'NNP'), ('and', 'CC'), ('Adrian', 'NNP')]
# NP [('The', 'DT'), ('way', 'NN'), ('Rocky', 'NNP')]
# NP [('her', 'PRP')]
# ...
# NP [('the', 'DT'), ('three', 'CD'), ('firsts', 'NNS'), ('films', 'NNS')]
# NP [('the', 'DT'), ('best', 'JJS'), ('one', 'NN')]
# NP [('it', 'PRP')]
# NP [('the', 'DT'), ('fourth', 'JJ'), ('part', 'NN')]
# NP [('the', 'DT'), ('series', 'NN')]
# NP [('another', 'DT'), ('way', 'NN')]
# NP [('films', 'NNS')]
# NP [('The', 'DT'), ('third', 'JJ'), ('part', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('the', 'DT'), ('top', 'NN')]
# NP [('the', 'DT'), ('ranking,he', 'NN')]
# NP [('his', 'PRP$'), ('wife', 'NN'), ('Adrian,his', 'DT'), ('son,Paul', 'NN')]
# NP [('Mickey', 'NNP')]
# NP [('Fights', 'NNS')]
# NP [('Easy', 'NNP'), ('combats', 'NNS'), ('but', 'CC'), ('One', 'CD'), ('Day', 'NNP')]
# NP [('a', 'DT'), ('new', 'JJ'), ('great', 'JJ'), ('boxer', 'NN'), ('appears,Clubber', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('the', 'DT'), ('Heavyweight', 'NNP'), ('champions', 'NNS')]
# NP [('it.In', 'NN'), ('the', 'DT'), ('combat', 'NN'), ('Rocky', 'NNP'), ('Fights', 'NNS')]
# NP [('his', 'PRP$'), ('coach', 'NN'), ('and', 'CC'), ('friend', 'NN'), ('Mickey', 'NNP')]
# NP [('Sick', 'NNP')]
# NP [('the', 'DT'), ('trainer', 'NN')]
# NP [('he', 'PRP')]
# NP [('he', 'PRP')]
# NP [('the', 'DT'), ('death', 'NN')]
# NP [('her', 'PRP$'), ('friend', 'NN')]
# NP [('the', 'DT'), ('help', 'NN')]
# NP [('Apollo', 'NNP'), ('Creed,begins', 'NNP')]
# NP [('Apollo', 'NNP')]
# NP [('old', 'JJ'), ('gym', 'NN')]
# NP [('he', 'PRP')]
# NP [('Lang', 'NNP')]
# NP [('Rocky', 'NNP'), ('III', 'NNP')]
# NP [('the', 'DT'), ('Best', 'NNP'), ('Sequel', 'NNP')]
# NP [('it', 'PRP')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky 3 Review Title: Fun, but not compelling.
# ===================================================================================
# NP [('The', 'DT'), ('third', 'JJ'), ('Rocky', 'NNP')]
# NP [('Stallone', 'NNP')]
# NP [('boxing', 'NN')]
# NP [('harassment', 'NN')]
# NP [('Mr.', 'NNP'), ('T.', 'NNP'), ('This', 'DT'), ('fun', 'NN')]
# NP [('less', 'JJR'), ('compelling', 'JJ'), ('entry', 'NN')]
# NP [('its', 'PRP$'), ('moments', 'NNS')]
# NP [('enjoyment', 'NN')]
# NP [('you', 'PRP')]
# NP [('he', 'PRP')]
# NP [('this', 'DT'), ('loser', 'NN')]
# NP [('the', 'DT'), ('first', 'JJ'), ('place', 'NN')]
# NP [('song', 'NN')]
# NP [('it', 'PRP')]
# NP [('you', 'PRP')]
# NP [('the', 'DT'), ('finale', 'NN')]
# NP [('their', 'PRP$'), ('own', 'JJ'), ('little', 'JJ'), ('way', 'NN')]
# NP [('this', 'DT'), ('one', 'NN')]
# NP [('a', 'DT'), ('bit', 'NN')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky 3 Review Title: Rocky V.S. Mr. T.
# ===================================================================================
# NP [('the', 'DT'), ('most', 'RBS'), ('popular', 'JJ'), ('Rocky', 'NNP'), ('movie', 'NN')]
# NP [('it', 'PRP')]
# NP [('the', 'DT'), ('versus', 'NN'), ('word', 'NN')]
# NP [('The', 'DT'), ('plot', 'NN')]
# NP [('part', 'NN'), ('II', 'NNP')]
# NP [('new', 'JJ'), ('characters', 'NNS')]
# NP [('a', 'DT'), ('plot', 'NN'), ('twist', 'NN')]
# NP [('the', 'DT'), ('principal', 'JJ'), ('fight', 'NN')]
# NP [('Mr.', 'NNP'), ('T.', 'NNP')]
# NP [('an', 'DT'), ('interesting', 'JJ'), ('choice', 'NN')]
# NP [('Rocky', 'NNP')]
# NP [('nemesis', 'NN')]
# NP [('the', 'DT'), ('ring', 'NN')]
# NP [('I', 'PRP')]
# NP [('his', 'PRP$'), ('presence', 'NN')]
# NP [('Mr.', 'NNP'), ('T.', 'NNP')]
# NP [('a', 'DT'), ('marketing', 'NN'), ('choice', 'NN')]
# NP [('it', 'PRP')]
# NP [('purpose', 'NN')]
# NP [('Heck', 'NNP')]
# NP [('he', 'PRP')]
# NP [('the', 'DT'), ('top', 'NN')]
# NP [('his', 'PRP$'), ('scenes', 'NNS')]
# NP [('The', 'DT'), ('dialogs', 'NNS')]
# NP [('it', 'PRP')]
# NP [('a', 'DT'), ('Rocky', 'NNP'), ('movie', 'NN')]
# NP [('You', 'PRP')]
# NP [('our', 'PRP$'), ('hero', 'NN')]
# NP [('the', 'DT'), ('worst', 'JJS'), ('situations', 'NNS')]
# NP [('winning', 'NN')]
# NP [('the', 'DT'), ('end', 'NN')]
# NP [('Rocky', 'NNP'), ('fans', 'NNS')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky 3 Review Title: Almost loses "The Eye of the Tiger" half-way through
# ===================================================================================
# NP [('Rocky', 'NNP'), ('Balboa', 'NNP')]
# NP [('Sylvester', 'NNP-PERS'), ('Stallone', 'NNP-PERS')]
# NP [('the', 'DT'), ('movie', 'NN')]
# NP [('the', 'DT'), ('Professional', 'JJ'), ('Boxing', 'NN'), ('World', 'NNP'), ('Heavyweight', 'NNP'), ('Champion', 'NNP')]
# NP [('the', 'DT'), ('life', 'NN'), ('he', 'PRP')]
# NP [('He', 'PRP')]
# NP [('a', 'DT'), ('huge', 'JJ'), ('house', 'NN')]
# NP [('his', 'PRP$'), ('family', 'NN')]
# NP [('the', 'DT'), ('cover', 'NN')]
# NP [('various', 'JJ'), ('magazines', 'NNS')]
# NP [('numerous', 'JJ'), ('endorsement', 'NN'), ('deals', 'NNS')]
# NP [('unknown', 'NN')]
# NP [('him', 'PRP')]
# NP [('he', 'PRP')]
# NP [('the', 'DT'), ('ring', 'NN')]
# NP [('the', 'DT'), ('point', 'NN')]
# NP [('his', 'PRP$'), ('manager', 'NN')]
# NP [('Mickey', 'NNP')]
# NP [('Burgess', 'NNP'), ('Meredith', 'NNP')]
# NP [('him', 'PRP')]
# NP [('bouts', 'NNS')]
# NP [('inferior', 'JJ'), ('fighters', 'NNS')]
# NP [('the', 'DT'), ('ring', 'NN')]
# NP [('the', 'DT'), ('cocky', 'JJ'), ('professional', 'JJ'), ('wrestling', 'NN'), ('star', 'NN')]
# NP [('Thunderlips', 'NNS')]
# NP [('Hulk', 'NNP'), ('Hogan', 'NNP')]
# NP [('his', 'PRP$'), ('acting', 'JJ'), ('debut', 'NN')]
# NP [('He', 'PRP')]
# NP [('his', 'PRP$'), ('edge', 'NN')]
# NP [('Mickey', 'NNP')]
# NP [('it', 'PRP')]
# NP [('the', 'DT'), ('champ', 'NN')]
# NP [('it', 'PRP')]
# NP [('He', 'PRP')]
# NP [('Mickey', 'NNP')]
# NP [('s', 'NN')]
# NP [('orders', 'NNS')]
# NP [('the', 'DT'), ('challenge', 'NN')]
# NP [('Clubber', 'NNP'), ('Lang', 'NNP')]
# NP [('Mr.', 'NNP'), ('T', 'NN')]
# NP [('his', 'PRP$'), ('most', 'RBS'), ('famous', 'JJ'), ('roles', 'NNS')]
# NP [('a', 'DT'), ('tough', 'JJ'), (',', ','), ('bad', 'JJ'), ('attitude', 'NN'), ('boxer', 'NN')]
# NP [('the', 'DT'), ('Number', 'NN')]
# NP [('One', 'CD'), ('Contendership', 'NN')]
# NP [('himself', 'PRP')]
# NP [('no', 'DT'), ('trainer', 'NN')]
# NP [('him', 'PRP')]
# NP [('Mickey', 'NNP')]
# NP [('Lang', 'NNP')]
# NP [('challenge', 'NN')]
# NP [('the', 'DT'), ('mohawked', 'JJ'), ('fighter', 'NN')]
# NP [('the', 'DT'), ('champ', 'NN')]
# NP [('wife', 'NN')]
# NP [('Talia', 'NNP'), ('Shire', 'NNP')]
# NP [('a', 'DT'), ('public', 'JJ'), ('appearance', 'NN')]
# NP [('He', 'PRP')]
# NP [('the', 'DT'), ('challenge', 'NN')]
# NP [('Mickey', 'NNP')]
# NP [('the', 'DT'), ('title', 'NN')]
# NP [('Lang', 'NNP')]
# NP [('things', 'NNS')]
# NP [('Mickey', 'NNP')]
# NP [('a', 'DT'), ('heart', 'NN'), ('attack', 'NN')]
# NP [('a', 'DT'), ('confrontation', 'NN')]
# NP [('Lang', 'NNP')]
# NP [('the', 'DT'), ('dressing', 'NN'), ('room', 'NN')]
# NP [('Lang', 'NNP')]
# NP [('the', 'DT'), ('champion', 'NN')]
# NP [('the', 'DT'), ('title', 'NN')]
# NP [('he', 'PRP')]
# NP [('he', 'PRP')]
# NP [('an', 'DT'), ('old', 'JJ'), ('rival', 'NN')]
# NP [('Carl', 'NNP'), ('Weathers', 'NNPS')]
# NP [('A', 'DT'), ('rival', 'NN')]
# NP [('Eye', 'NNP')]
# NP [('the', 'DT'), ('Tiger', 'NNP')]
# NP [('he', 'PRP')]
# NP [('The', 'DT'), ('Italian', 'JJ'), ('Stallion', 'NN')]
# NP [('himself', 'PRP')]
# NP [('the', 'DT'), ('title', 'NN')]
# NP [('movie', 'NN')]
# NP [('the', 'DT'), ('film', 'NN')]
# NP [('I', 'PRP')]
# NP [('myself', 'PRP')]
# NP [('websites', 'NNS')]
# NP [('that', 'DT'), ('time', 'NN')]
# NP [('the', 'DT'), ('film', 'NN')]
# NP [('Demand', 'NN')]
# NP [('It', 'PRP')]
# NP [('the', 'DT'), ('rematch', 'NN')]
# NP [('the', 'DT'), ('two', 'CD'), ('boxing', 'NN'), ('rivals', 'NNS')]
# NP [('the', 'DT'), ('time', 'NN')]
# NP [('Apollo', 'NNP'), ('Creed', 'NNP')]
# NP [('The', 'DT'), ('acting', 'NN')]
# NP [('You', 'PRP')]
# NP [('he', 'PRP')]
# NP [('his', 'PRP$'), ('edge', 'NN')]
# NP [('Stallone', 'NNP')]
# NP [('performance', 'NN')]
# NP [('the', 'DT'), ('scene', 'NN')]
# NP [('the', 'DT'), ('death', 'NN')]
# NP [('Mickey', 'NNP')]
# NP [('him', 'PRP')]
# NP [('Certain', 'NNP')]
# NP [('members', 'NNS')]
# NP [('characters', 'NNS')]
# NP [('two', 'CD'), ('movies', 'NNS')]
# NP [('I', 'PRP')]
# NP [('they', 'PRP')]
# NP [('they', 'PRP')]
# NP [('the', 'DT'), ('storyline', 'NN')]
# NP [('they', 'PRP')]
# NP [('part', 'NN')]
# NP [('the', 'DT'), ('series', 'NN')]
# NP [('the', 'DT'), ('first', 'JJ'), ('movie', 'NN')]
# NP [('the', 'DT'), ('franchise', 'NN')]
# NP [('I', 'PRP')]
# NP [('the', 'DT'), ('chemistry', 'NN')]
# NP [('Stallone', 'NNP'), ('and', 'CC'), ('Weathers', 'NNPS')]
# NP [('this', 'DT'), ('film', 'NN')]
# NP [('previous', 'JJ'), ('films', 'NNS')]
# NP [('they', 'PRP')]
# NP [('rivals', 'NNS')]
# NP [('they', 'PRP')]
# NP [('the', 'DT'), ('same', 'JJ'), ('side', 'NN')]
# NP [('They', 'PRP')]
# NP [('two', 'CD'), ('professionals', 'NNS')]
# NP [('the', 'DT'), ('toughest', 'JJS'), ('sports', 'NNS')]
# NP [('the', 'DT'), ('planet', 'NN')]
# NP [('a', 'DT'), ('teacher', 'NN')]
# NP [('a', 'DT'), ('rival', 'NN')]
# NP [('the', 'DT'), ('title', 'NN')]
# NP [('his', 'PRP$'), ('now-student', 'NN')]
# NP [('Weathers', 'NNPS')]
# NP [('this', 'DT'), ('role', 'NN')]
# NP [('the', 'DT'), ('audience', 'NN')]
# NP [('arrogant', 'JJ'), ('he', 'PRP')]
# NP [('six', 'CD'), ('years', 'NNS')]
# NP [('the', 'DT'), ('first', 'JJ'), ('movie', 'NN')]
# NP [('Another', 'DT'), ('breakout', 'NN'), ('performance', 'NN')]
# NP [('Mr.', 'NNP'), ('T.', 'NNP')]
# NP [('his', 'PRP$'), ('edge', 'NN')]
# NP [('Lang', 'NNP')]
# NP [('The', 'DT'), ('film', 'NN')]
# NP [('training', 'NN')]
# NP [('the', 'DT'), ('rematch', 'NN')]
# NP [('Lang', 'NNP')]
# NP [('the', 'DT'), ('life', 'NN')]
# NP [('champion', 'NN')]
# NP [('You', 'PRP')]
# NP [('he', 'PRP')]
# NP [('the', 'DT'), ('movie', 'NN')]
# NP [('he', 'PRP')]
# NP [('the', 'DT'), ('story', 'NN')]
# NP [('the', 'DT'), ('rematch', 'NN')]
# NP [('I', 'PRP')]
# NP [('some', 'DT'), ('references', 'NNS')]
# NP [('Lang', 'NNP')]
# NP [('training', 'NN')]
# NP [('the', 'DT'), ('role', 'NN')]
# NP [('Mr.', 'NNP'), ('T', 'NN'), ('his', 'PRP$'), ('tough', 'JJ'), ('guy', 'NN'), ('image', 'NN')]
# NP [('He', 'PRP')]
# NP [('the', 'DT'), ('bad', 'JJ'), ('guy', 'NN'), ('you', 'PRP')]
# NP [('This', 'DT'), ('film', 'NN')]
# NP [('You', 'PRP')]
# NP [('the', 'DT'), ('end', 'NN')]
# NP [('I', 'PRP')]
# NP [('some', 'DT'), ('plot', 'NN'), ('twists', 'NNS')]
# NP [('the', 'DT'), ('end', 'NN')]
# NP [('Another', 'DT'), ('problem', 'NN')]
# NP [('this', 'DT'), ('film', 'NN')]
# NP [('the', 'DT'), ('soundtrack', 'NN')]
# NP [('I', 'PRP')]
# NP [('two', 'CD'), ('songs', 'NNS')]
# NP [('the', 'DT'), ('film', 'NN')]
# NP [('Rocky', 'NNP'), ('Theme', 'NNP')]
# NP [('piece', 'NN')]
# NP [('so', 'RB'), ('recognizable', 'JJ'), ('now', 'RB'), ('you', 'PRP')]
# NP [('it', 'PRP')]
# NP [('Eye', 'NNP')]
# NP [('the', 'DT'), ('Tiger', 'NNP')]
# NP [('this', 'DT'), ('song', 'NN')]
# NP [('Survivor', 'NNP')]
# NP [('Another', 'DT'), ('problem', 'NN')]
# NP [('this', 'DT'), ('film', 'NN')]
# NP [('times', 'NNS')]
# NP [('it', 'PRP')]
# NP [('Stallone', 'NNP')]
# NP [('speaking', 'NN')]
# NP [('times', 'NNS')]
# NP [('I', 'PRP')]
# NP [('others', 'NNS')]
# NP [('the', 'DT'), ('scene', 'NN')]
# NP [('response', 'NN')]
# NP [('you', 'PRP')]
# NP [('the', 'DT'), ('other', 'JJ'), ('movies', 'NNS')]
# NP [('I', 'PRP')]
# NP [('this', 'DT'), ('film', 'NN')]
# NP [('VHS/DVD', 'NNP')]
# NP [('the', 'DT'), ('series', 'NN')]
# NP [('I', 'PRP')]
# NP [('a', 'DT'), ('pretty', 'JJ'), ('good', 'JJ'), ('third', 'JJ'), ('choice', 'NN')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# ===================================================================================
# ===  Movie: Rocky 3 Review Title: Not pitiable... though not far off from it, either
# ===================================================================================
# NP [('Our', 'PRP$'), ('protagonist(Sly', 'NN')]
# NP [('everyman', 'NN')]
# NP [('spite', 'NN')]
# NP [('greater', 'JJR'), ('fame', 'NN')]
# NP [('wealth', 'NN')]
# NP [('the', 'DT'), ('up-and-comer', 'NN')]
# NP [('Clubber', 'NNP'), ('Lang(Mr', 'NNP')]
# NP [('T', 'NN')]
# NP [('his', 'PRP$'), ('tough', 'JJ'), ('image', 'NN')]
# NP [('a', 'DT'), ('fear', 'NN')]
# NP [('He', 'PRP')]
# NP [('fortunate', 'JJ'), ('assault', 'NN'), ('laws', 'NNS')]
# NP [('the', 'DT'), ('ring', 'NN')]
# NP [('he', 'PRP')]
# NP [('his', 'PRP$'), ('underdog', 'NN'), ('status', 'NN')]
# NP [('Mickey', 'NNP')]
# NP [('s(still', 'NN'), ('intense', 'JJ'), ('Meredith', 'NNP')]
# NP [('health', 'NN')]
# NP [('he', 'PRP')]
# NP [('the', 'DT'), ('great', 'JJ'), ('big', 'JJ'), ('cold', 'JJ'), ('continent', 'NN')]
# NP [('the', 'DT'), ('sky', 'NN')]
# NP [('Adrian(Shire', 'NNP')]
# NP [('shy', 'NN')]
# NP [('They', 'PRP')]
# NP [('her', 'PRP'), ('this', 'DT'), ('time', 'NN')]
# NP [('It', 'PRP')]
# NP [('the', 'DT'), ('love', 'NN')]
# NP [('the', 'DT'), ('elements', 'NNS')]
# NP [('us', 'PRP')]
# NP [('the', 'DT'), ('macho', 'JJ'), ('crap', 'NN')]
# NP [('I', 'PRP')]
# NP [('sale', 'NN')]
# NP [('they', 'PRP')]
# NP [('her', 'PRP$'), ('support', 'NN'), ('him', 'PRP')]
# NP [('they', 'PRP')]
# NP [('her', 'PRP')]
# NP [('Paulie', 'NNP')]
# NP [('s(Young', 'NN')]
# NP [('racism', 'NN')]
# NP [('the', 'DT'), ('forefront', 'NN')]
# NP [('Creed(Weathers', 'NNS')]
# NP [('Duke(Burton', 'NNP')]
# NP [('unlikely', 'JJ'), ('allies', 'NNS')]
# NP [('It', 'PRP')]
# NP [('a', 'DT'), ('matter', 'NN')]
# NP [('time', 'NN')]
# NP [('they', 'PRP')]
# NP [('one', 'CD'), ('actual', 'JJ'), ('fighter', 'NN')]
# NP [('an', 'DT'), ('actor', 'NN')]
# NP [('former', 'JJ'), ('football', 'NN'), ('player', 'NN')]
# NP [('we', 'PRP')]
# NP [('Wrong', 'JJ'), ('sport', 'NN')]
# NP [('course', 'NN')]
# NP [('least', 'JJS'), ('it', 'PRP')]
# NP [('the', 'DT'), ('right', 'JJ'), ('direction', 'NN')]
# NP [('the', 'DT'), ('fights', 'NNS')]
# NP [('wrestling', 'NN')]
# NP [('the', 'DT'), ('time', 'NN')]
# NP [('writing', 'NN')]
# NP [('I', 'PRP')]
# NP [('this', 'DT'), ('point', 'NN')]
# NP [('the', 'DT'), ('franchise', 'NN')]
# NP [('my', 'PRP$'), ('mind', 'NN')]
# NP [('I', 'PRP')]
# NP [('the', 'DT'), ('second', 'JJ'), ('installment', 'NN')]
# NP [('one', 'CD'), ('movie', 'NN')]
# NP [('I', 'PRP')]
# NP [('me', 'PRP')]
# NP [('Part', 'NN')]
# NP [('the', 'DT'), ('point', 'NN')]
# NP [('he', 'PRP')]
# NP [('it', 'PRP')]
# NP [('his', 'PRP$'), ('last', 'JJ'), ('chance', 'NN')]
# NP [('The', 'DT'), ('problem', 'NN')]
# NP [('a', 'DT'), ('series', 'NN')]
# NP [('this', 'DT'), ('genre', 'NN')]
# NP [('we', 'PRP')]
# NP [('it', 'PRP')]
# NP [('a', 'DT'), ('climactic', 'JJ'), ('showdown', 'NN')]
# NP [('Action', 'NNP'), ('flicks', 'NNS')]
# NP [('thrillers', 'NNS')]
# NP [('dramas', 'NN')]
# NP [('it', 'PRP')]
# NP [('the', 'DT'), ('consequences', 'NNS')]
# NP [('one', 'CD'), ('way', 'NN')]
# NP [('it', 'PRP')]
# NP [('stakes', 'NNS')]
# NP [('We', 'PRP')]
# NP [('it', 'PRP')]
# NP [('the', 'DT'), ('signs', 'NNS')]
# NP [('Anything', 'NN')]
# NP [('we', 'PRP')]
# NP [('it', 'PRP')]
# NP [('You', 'PRP')]
# NP [('it', 'PRP')]
# NP [('the', 'DT'), ('rules', 'NNS')]
# NP [('that', 'DT'), ('territory', 'NN')]
# NP [('92', 'CD'), ('and', 'CC'), ('a', 'DT'), ('half', 'NN'), ('minutes', 'NNS')]
# NP [('credits', 'NNS')]
# NP [('95', 'CD'), ('and', 'CC'), ('a', 'DT'), ('half', 'NN')]
# NP [('a', 'DT'), ('lot', 'NN')]
# NP [('brutal', 'JJ'), ('boxing', 'NN')]
# NP [('some', 'DT'), ('strong', 'JJ'), ('language', 'NN')]
# NP [('I', 'PRP')]
# NP [('it', 'PRP')]
# NP [('completionists', 'NNS')]
# ===================================================================================
# =================================== End Review ====================================
# ===================================================================================
# Wall time: 2min 28s
